# %% [markdown]
# # Enriquecimiento de la capa Plata

# %% [markdown]
# En esta notebook trabajaremos sobre los datos horarios previamente generados y la capa Plata intermedia con el objetivo de **enriquecer y completar la información** antes de su uso para análisis avanzados (clustering, PCA, reglas de asociación, etc.).
#
# ### Las principales tareas realizadas son:
# - Detección de fechas y horas con datos faltantes.
# - Imputación de valores `NaN` basados en el promedio del mismo horario del día anterior y posterior.
# - Comparación entre el dataset original y el imputado.
# - Exportación del dataset horario imputado.
# - Verificación final de la cobertura completa de fechas por estación.

# %% [markdown]
# ## Importar las librerías necesarias

# %%
import pandas as pd
from pathlib import Path
import warnings

# Deshabilitar warnings futuros
warnings.simplefilter(action='ignore', category=FutureWarning)

# Ajustar el ancho máximo para impresión en consola
pd.set_option('display.max_columns', None)  # Mostrar todas las columnas
pd.set_option('display.width', 300)         # Ajustar a un ancho suficiente en consola
pd.set_option('display.max_colwidth', None) # Evitar recortes en contenido de celdas

print("Importación de librerías completada.")
# Out:
# Importación de librerías completada.

# %% [markdown]
# ## Configuración de paths y carpetas del proyecto

# %%
BASE_DIR = Path('..').resolve()
RAW_DIR = BASE_DIR / 'data' / 'raw'
BRONCE_DIR = BASE_DIR / 'data' / 'bronce'
PLATA_DIR = Path("../data/plata")

archivo_plata = PLATA_DIR / "dataset_plata_inicial.csv"
archivo_horario = PLATA_DIR / "horario_archivo.csv"

print("Iniciación de carpetas del proyecto completada.")
# Out:
# Iniciación de carpetas del proyecto completada.

# %% [markdown]
# ## Carga del dataset y verificación de estructura

# %%
# Cargar el dataset diario
try:
    df_plata = pd.read_csv(archivo_plata, parse_dates=["FECHA"])
    print("Dataset diario cargado correctamente")
except FileNotFoundError:
    print("El archivo diario no fue encontrado")

# Cargar el dataset horario
try:
    df_horario = pd.read_csv(archivo_horario, parse_dates=["FECHA_HORA"])
    print("Dataset horario cargado correctamente")
except FileNotFoundError:
    print("El archivo horario no fue encontrado")

# Vista preliminar
print("\n Dataset diario:")
df_plata.info()
print("\n")
print(df_plata.head())

print("\n Dataset horario:")
df_horario.info()
print("\n")
print(df_horario.head())
# Out:
# Dataset diario cargado correctamente
# Dataset horario cargado correctamente
#
#  Dataset diario:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2954 entries, 0 to 2953
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ESTACION              2954 non-null   object
#  1   FECHA                 2954 non-null   datetime64[ns]
#  2   TEMP_MEAN             2954 non-null   float64
#  3   TEMP_MIN              2954 non-null   float64
#  4   TEMP_MAX              2954 non-null   float64
#  5   PNM_MEAN              2954 non-null   float64
#  6   PNM_MIN               2954 non-null   float64
#  7   PNM_MAX               2954 non-null   float64
#  8   HUM_MEAN              2954 non-null   float64
#  9   HUM_MIN               2954 non-null   int64
#  10  HUM_MAX               2954 non-null   int64
#  11  WIND_DIR_MEAN         2954 non-null   float64
#  12  WIND_DIR_MIN          2954 non-null   int64
#  13  WIND_DIR_MAX          2954 non-null   int64
#  14  WIND_SPEED_MEAN       2954 non-null   float64
#  15  WIND_SPEED_MIN        2954 non-null   int64
#  16  WIND_SPEED_MAX        2954 non-null   int64
#  17  TEMP_MEAN_NORM        2954 non-null   float64
#  18  PNM_MEAN_NORM         2954 non-null   float64
#  19  HUM_MEAN_NORM         2954 non-null   float64
#  20  WIND_DIR_MEAN_NORM    2954 non-null   float64
#  21  WIND_SPEED_MEAN_NORM  2954 non-null   float64
# dtypes: datetime64[ns](1), float64(14), int64(6), object(1)
# memory usage: 507.8+ KB
#
#
#      ESTACION      FECHA  TEMP_MEAN  TEMP_MIN  TEMP_MAX  PNM_MEAN  PNM_MIN  PNM_MAX  HUM_MEAN  HUM_MIN  HUM_MAX  WIND_DIR_MEAN  WIND_DIR_MIN  WIND_DIR_MAX  WIND_SPEED_MEAN  WIND_SPEED_MIN  WIND_SPEED_MAX  TEMP_MEAN_NORM  PNM_MEAN_NORM  HUM_MEAN_NORM  WIND_DIR_MEAN_NORM  WIND_SPEED_MEAN_NORM
# 0  CERES AERO 2024-06-01       17.7      11.2      25.8    1012.5   1010.4   1014.6      75.3       50       96          190.0            20           360              6.1               4              15        0.473684       0.410256       0.661473            0.504806              0.117359
# 1  CERES AERO 2024-06-02       17.4      14.2      24.5    1014.6   1008.9   1026.6      71.2       38       94          214.2            50           360             19.0               4              56        0.464912       0.464103       0.603399            0.575299              0.432763
# 2  CERES AERO 2024-06-03       12.1       6.6      16.6    1028.1   1024.9   1032.0      49.5       31       71          149.2            90           180             15.0               4              24        0.309942       0.810256       0.296034            0.385960              0.334963
# 3  CERES AERO 2024-06-04       12.2       9.2      16.0    1021.0   1017.4   1025.5      68.8       51       82           75.4             0            90             11.0               0              15        0.312865       0.628205       0.569405            0.170987              0.237164
# 4  CERES AERO 2024-06-05       16.2      12.0      23.2    1015.7   1012.2   1019.1      74.0       45       89          142.5             0           360              6.5               0              15        0.429825       0.492308       0.643059            0.366443              0.127139
#
#  Dataset horario:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59282 entries, 0 to 59281
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   FECHA             59282 non-null  object
#  1   HORA              59282 non-null  int64
#  2   TEMP              59282 non-null  float64
#  3   HUM               59282 non-null  int64
#  4   PNM               59282 non-null  float64
#  5   DD                59282 non-null  int64
#  6   FF                59282 non-null  int64
#  7   NOMBRE            59282 non-null  object
#  8   estacion_archivo  59282 non-null  int64
#  9   FECHA_HORA        59282 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(5), object(2)
# memory usage: 4.5+ MB
#
#
#         FECHA  HORA  TEMP  HUM     PNM  DD  FF            NOMBRE  estacion_archivo          FECHA_HORA
# 0  2024-11-02     0  25.8   74  1003.5  50  22  SAUCE VIEJO AERO          20241102 2024-11-02 00:00:00
# 1  2024-11-02     1  25.6   73  1003.7  70  24  SAUCE VIEJO AERO          20241102 2024-11-02 01:00:00
# 2  2024-11-02     2  24.7   76  1004.3  50  19  SAUCE VIEJO AERO          20241102 2024-11-02 02:00:00
# 3  2024-11-02     3  23.6   81  1004.8  50  13  SAUCE VIEJO AERO          20241102 2024-11-02 03:00:00
# 4  2024-11-02     4  22.4   88  1005.1  50   7  SAUCE VIEJO AERO          20241102 2024-11-02 04:00:00

# %% [markdown]
# Este paso permite validar la estructura general, tipos de datos y posibles columnas faltantes tanto en el dataset diario como en el horario. Si todo está correcto, avanzaremos con el enriquecimiento.

# %% [markdown]
# ## Detección y análisis de fechas faltantes
#
# Una vez verificada la estructura del dataset diario, procedemos a identificar si existen fechas faltantes en la serie por estación.
#
# Esto nos permitirá decidir estrategias para tratar los días sin registros, como imputación o exclusión.

# %%
# Generar el rango completo de fechas esperadas
fechas_totales = pd.date_range(start=df_plata['FECHA'].min(), end=df_plata['FECHA'].max(), freq='D')

# Obtener todas las combinaciones posibles de fecha y estación
estaciones = df_plata['ESTACION'].unique()
index_completo = pd.MultiIndex.from_product([fechas_totales, estaciones], names=['FECHA', 'ESTACION'])

# Reindexar para insertar NaNs explícitos en las fechas faltantes
df_plata = df_plata.set_index(['FECHA', 'ESTACION']).reindex(index_completo).reset_index()

# Verificar fechas faltantes (para exportar listado)
faltantes = df_plata[df_plata.isnull().any(axis=1)][['ESTACION', 'FECHA']]

if not faltantes.empty:
    faltantes.to_csv(PLATA_DIR / "fechas_faltantes.txt", index=False, sep='\t')
    print("Fechas faltantes exportadas a:", PLATA_DIR / "fechas_faltantes.txt")
else:
    print("No se encontraron fechas faltantes")

# Mostrar ejemplo si hay faltantes
print(faltantes.head())
# Out:
# Fechas faltantes exportadas a: ../data/plata/fechas_faltantes.txt
#               ESTACION      FECHA
# 1015        CERES AERO 2024-10-24
# 1016      RAFAELA AERO 2024-10-24
# 1017  RECONQUISTA AERO 2024-10-24
# 1018      ROSARIO AERO 2024-10-24
# 1019  SAUCE VIEJO AERO 2024-10-24

# %% [markdown]
# Esta estrategia asegura que cada estación tenga una fila para cada fecha del rango, incluso si originalmente no había registros ese día. Esto deja los valores faltantes como `NaN`, que luego se tratarán.

# %% [markdown]
# ## Tratamiento de valores nulos
#
# Luego de verificar fechas faltantes, analizamos los valores `NaN` dentro del dataset actual para decidir estrategias de imputación o tratamiento.

# %% [markdown]
# ### Tratamiento de datos faltantes en el dataset diario

# %%
# Visualizar cantidad de nulos por columna
print("\nValores nulos por columna:")
print(df_plata.isnull().sum())

# Calcular porcentaje de nulos por columna
porcentaje_nulos = df_plata.isnull().mean() * 100
print("\nPorcentaje de valores nulos:")
print(porcentaje_nulos.round(2))
# Out:
# Valores nulos por columna:
# FECHA                    0
# ESTACION                 0
# TEMP_MEAN               28
# TEMP_MIN                28
# TEMP_MAX                28
# PNM_MEAN                28
# PNM_MIN                 28
# PNM_MAX                 28
# HUM_MEAN                28
# HUM_MIN                 28
# HUM_MAX                 28
# WIND_DIR_MEAN           28
# WIND_DIR_MIN            28
# WIND_DIR_MAX            28
# WIND_SPEED_MEAN         28
# WIND_SPEED_MIN          28
# WIND_SPEED_MAX          28
# TEMP_MEAN_NORM          28
# PNM_MEAN_NORM           28
# HUM_MEAN_NORM           28
# WIND_DIR_MEAN_NORM      28
# WIND_SPEED_MEAN_NORM    28
# dtype: int64
#
# Porcentaje de valores nulos:
# FECHA                   0.00
# ESTACION                0.00
# TEMP_MEAN               0.94
# TEMP_MIN                0.94
# TEMP_MAX                0.94
# PNM_MEAN                0.94
# PNM_MIN                 0.94
# PNM_MAX                 0.94
# HUM_MEAN                0.94
# HUM_MIN                 0.94
# HUM_MAX                 0.94
# WIND_DIR_MEAN           0.94
# WIND_DIR_MIN            0.94
# WIND_DIR_MAX            0.94
# WIND_SPEED_MEAN         0.94
# WIND_SPEED_MIN          0.94
# WIND_SPEED_MAX          0.94
# TEMP_MEAN_NORM          0.94
# PNM_MEAN_NORM           0.94
# HUM_MEAN_NORM           0.94
# WIND_DIR_MEAN_NORM      0.94
# WIND_SPEED_MEAN_NORM    0.94
# dtype: float64

# %% [markdown]
# Una vez identificadas las columnas afectadas, proponemos distintas estrategias para completar los datos:

# %% [markdown]
# ### Relleno con forward fill por estación

# %%
# Ordenar por estación y fecha para aplicar forward fill correctamente
df_plata_ffill = df_plata.sort_values(['ESTACION', 'FECHA']).copy()
df_plata_ffill.update(df_plata.groupby('ESTACION').ffill())

# Vista previa de ejemplo tras forward fill
print("\nEjemplo de datos tras forward fill:")
print(df_plata_ffill.head())
# Out:
# Ejemplo de datos tras forward fill:
#         FECHA    ESTACION  TEMP_MEAN  TEMP_MIN  TEMP_MAX  PNM_MEAN  PNM_MIN  PNM_MAX  HUM_MEAN  HUM_MIN  HUM_MAX  WIND_DIR_MEAN  WIND_DIR_MIN  WIND_DIR_MAX  WIND_SPEED_MEAN  WIND_SPEED_MIN  WIND_SPEED_MAX  TEMP_MEAN_NORM  PNM_MEAN_NORM  HUM_MEAN_NORM  WIND_DIR_MEAN_NORM  WIND_SPEED_MEAN_NORM
# 0  2024-06-01  CERES AERO       17.7      11.2      25.8    1012.5   1010.4   1014.6      75.3     50.0     96.0          190.0          20.0         360.0              6.1             4.0            15.0        0.473684       0.410256       0.661473            0.504806              0.117359
# 7  2024-06-02  CERES AERO       17.4      14.2      24.5    1014.6   1008.9   1026.6      71.2     38.0     94.0          214.2          50.0         360.0             19.0             4.0            56.0        0.464912       0.464103       0.603399            0.575299              0.432763
# 14 2024-06-03  CERES AERO       12.1       6.6      16.6    1028.1   1024.9   1032.0      49.5     31.0     71.0          149.2          90.0         180.0             15.0             4.0            24.0        0.309942       0.810256       0.296034            0.385960              0.334963
# 21 2024-06-04  CERES AERO       12.2       9.2      16.0    1021.0   1017.4   1025.5      68.8     51.0     82.0           75.4           0.0          90.0             11.0             0.0            15.0        0.312865       0.628205       0.569405            0.170987              0.237164
# 28 2024-06-05  CERES AERO       16.2      12.0      23.2    1015.7   1012.2   1019.1      74.0     45.0     89.0          142.5           0.0         360.0              6.5             0.0            15.0        0.429825       0.492308       0.643059            0.366443              0.127139

# %% [markdown]
# ### Imputación con la media de cada estación (solo para columnas numéricas)

# %%
# Imputar con la media por estación
columnas_a_imputar = ['TEMP_MEAN', 'PNM_MEAN', 'HUM_MEAN', 'WIND_SPEED_MEAN', 'WIND_DIR_MEAN']

for col in columnas_a_imputar:
    df_plata_ffill[col] = df_plata_ffill.groupby('ESTACION')[col].transform(lambda x: x.fillna(x.mean()))

# Verificar resultado tras imputación
print("\nValores nulos después de imputación con medias:")
print(df_plata_ffill[columnas_a_imputar].isnull().sum())
# Out:
# Valores nulos después de imputación con medias:
# TEMP_MEAN          0
# PNM_MEAN           0
# HUM_MEAN           0
# WIND_SPEED_MEAN    0
# WIND_DIR_MEAN      0
# dtype: int64

# %% [markdown]
# Estas estrategias permiten garantizar que las variables derivadas a construir se basen en datos consistentes, sin afectar la distribución ni introducir sesgos evidentes.

# %% [markdown]
# ### Tratamiento de datos faltantes en el dataset horario

# %%
# Detectar horarios reales de cada estación
df_horario['HORA'] = df_horario['FECHA_HORA'].dt.hour
horarios_por_estacion = df_horario.groupby('NOMBRE')['HORA'].value_counts().unstack(fill_value=0)
horarios_mas_frecuentes = horarios_por_estacion.idxmax(axis=1)

# Detectar horarios outlier (menos del 5% de los días)
outliers_horarios = {}
for estacion in horarios_por_estacion.index:
    total_dias = df_horario[df_horario['NOMBRE'] == estacion]['FECHA_HORA'].dt.date.nunique()
    outliers = horarios_por_estacion.loc[estacion][
        horarios_por_estacion.loc[estacion] / total_dias < 0.05
    ].index.tolist()
    if outliers:
        outliers_horarios[estacion] = outliers

# Crear index completo por estación y sus horarios típicos
df_horario['FECHA'] = df_horario['FECHA_HORA'].dt.floor('D')
estaciones_h = df_horario['NOMBRE'].unique()
fecha_h_min = df_horario['FECHA'].min()
fecha_h_max = df_horario['FECHA'].max()
rango_fechas = pd.date_range(start=fecha_h_min, end=fecha_h_max, freq='D')

# Crear combinaciones válidas por estación
porcentaje_frecuencia = 0.05 # al menos en 5% de los días

index_completo_personalizado = []
for estacion in estaciones_h:
    total_dias_estacion = df_horario[df_horario['NOMBRE'] == estacion]['FECHA'].nunique()
    horas_validas = horarios_por_estacion.columns[
        (horarios_por_estacion.loc[estacion] / total_dias_estacion) >= porcentaje_frecuencia  
    ].tolist()

    for fecha in rango_fechas:
        for hora in horas_validas:
            index_completo_personalizado.append((estacion, pd.Timestamp(fecha + pd.Timedelta(hours=hora))))

index_completo_h = pd.MultiIndex.from_tuples(index_completo_personalizado, names=['NOMBRE', 'FECHA_HORA'])

# Reindexar para insertar valores faltantes en los horarios esperados únicamente
df_horario_completo = df_horario.set_index(['NOMBRE', 'FECHA_HORA']).reindex(index_completo_h).reset_index()

# Verificación
print("\nDiferencia de tamaño (horas originales vs completadas por horario habitual):")
print("Original:", len(df_horario))
print("Completo:", len(df_horario_completo))
print("\nEjemplo de datos horarios con NaN insertados:")
print(df_horario_completo[df_horario_completo.isnull().any(axis=1)].head())
# Out:
# Diferencia de tamaño (horas originales vs completadas por horario habitual):
# Original: 59282
# Completo: 60492
#
# Ejemplo de datos horarios con NaN insertados:
#                 NOMBRE          FECHA_HORA FECHA  HORA  TEMP  HUM  PNM  DD  FF  estacion_archivo
# 1360  SAUCE VIEJO AERO 2024-07-27 16:00:00   NaT   NaN   NaN  NaN  NaN NaN NaN               NaN
# 3308  SAUCE VIEJO AERO 2024-10-16 20:00:00   NaT   NaN   NaN  NaN  NaN NaN NaN               NaN
# 3480  SAUCE VIEJO AERO 2024-10-24 00:00:00   NaT   NaN   NaN  NaN  NaN NaN NaN               NaN
# 3481  SAUCE VIEJO AERO 2024-10-24 01:00:00   NaT   NaN   NaN  NaN  NaN NaN NaN               NaN
# 3482  SAUCE VIEJO AERO 2024-10-24 02:00:00   NaT   NaN   NaN  NaN  NaN NaN NaN               NaN

# %% [markdown]
# ### Mostrar horarios outliers detectados

# %%
# Visualizar registros reales en horarios atípicos detectados
print("\n Registros reales en horarios atípicos:")
for estacion, horas in outliers_horarios.items():
    print(f" - {estacion}: {horas}")

# Registrar los registros reales que ocurren en horarios atípicos
df_outliers_registros = []
for estacion, horas_outlier in outliers_horarios.items():
    registros_outlier = df_horario[
        (df_horario['NOMBRE'] == estacion) &
        (df_horario['HORA'].isin(horas_outlier))
    ]
    if not registros_outlier.empty:
        df_outliers_registros.append(registros_outlier)

# Concatenar y exportar si hay registros
if df_outliers_registros:
    df_outliers_concat = pd.concat(df_outliers_registros)
    archivo_outliers = PLATA_DIR / "registros_horarios_atipicos.csv"
    df_outliers_concat.to_csv(archivo_outliers, index=False)
    print("\n Archivo exportado con registros reales en horarios atípicos:")
    print(archivo_outliers)
# Out:
#  Registros reales en horarios atípicos:
#  - RAFAELA AERO: [0, 1, 2, 3, 4, 5, 7, 8, 10, 11, 13, 14, 16, 17, 19, 20, 22, 23]
#  - VENADO TUERTO AERO: [0, 1, 2, 3, 4, 5, 22, 23]
#
#  Archivo exportado con registros reales en horarios atípicos:
# ../data/plata/registros_horarios_atipicos.csv

# %% [markdown]
# ## Exportar datasets intermedios (antes de procesar los NaN)

# %%
# Exportar datasets intermedios (si se desea conservar)
df_plata.to_csv(PLATA_DIR / "dataset_intermedio_horario_con_nan.csv", index=False)
df_plata_ffill.to_csv(PLATA_DIR / "dataset_intermedio_horario_ffill.csv", index=False)
df_horario_completo.to_csv(PLATA_DIR / "dataset_intermedio_horario_completo.csv", index=False)

print("Archivos generados correctamente")
# Out:
# Archivos generados correctamente

# %%
print(df_horario_completo)
# Out:
#                  NOMBRE          FECHA_HORA      FECHA  HORA  TEMP   HUM     PNM     DD    FF  estacion_archivo
# 0      SAUCE VIEJO AERO 2024-06-01 00:00:00 2024-06-01   0.0  14.6  88.0  1014.4   50.0  17.0        20240601.0
# 1      SAUCE VIEJO AERO 2024-06-01 01:00:00 2024-06-01   1.0  14.1  89.0  1014.0   90.0   7.0        20240601.0
# 2      SAUCE VIEJO AERO 2024-06-01 02:00:00 2024-06-01   2.0  13.5  91.0  1013.8   50.0   9.0        20240601.0
# 3      SAUCE VIEJO AERO 2024-06-01 03:00:00 2024-06-01   3.0  13.4  92.0  1013.0   50.0  11.0        20240601.0
# 4      SAUCE VIEJO AERO 2024-06-01 04:00:00 2024-06-01   4.0  14.1  89.0  1013.0   90.0   7.0        20240601.0
# ...                 ...                 ...        ...   ...   ...   ...     ...    ...   ...               ...
# 60487      RAFAELA AERO 2025-07-31 09:00:00 2025-07-31   9.0  14.6  74.0  1011.0   50.0  24.0        20250731.0
# 60488      RAFAELA AERO 2025-07-31 12:00:00 2025-07-31  12.0  16.1  63.0  1010.1   50.0  15.0        20250731.0
# 60489      RAFAELA AERO 2025-07-31 15:00:00 2025-07-31  15.0  16.4  61.0  1007.5   70.0  15.0        20250731.0
# 60490      RAFAELA AERO 2025-07-31 18:00:00 2025-07-31  18.0  18.8  69.0  1004.5  110.0   9.0        20250731.0
# 60491      RAFAELA AERO 2025-07-31 21:00:00 2025-07-31  21.0  19.9  60.0  1005.8   50.0  24.0        20250731.0
#
# [60492 rows x 10 columns]

# %% [markdown]
# ## Imputación de datos faltantes basada en promedio entre días anterior y posterior

# %%
# Variables a imputar
variables_objetivo = ['TEMP', 'HUM', 'PNM', 'DD', 'FF']

df_interp = df_horario_completo.copy()

# Asegurar FECHA y HORA correctas
df_interp['FECHA'] = df_interp['FECHA_HORA'].dt.date
df_interp['HORA'] = df_interp['FECHA_HORA'].dt.hour

# Ordenar por estación, fecha y hora
df_interp = df_interp.sort_values(by=['NOMBRE', 'FECHA', 'HORA'])

# Función de imputación por promedio entre día anterior y posterior
def imputar_valores(grupo):
    grupo = grupo.copy()  # para evitar advertencias de SettingWithCopy
    for var in variables_objetivo:
        for idx, fila in grupo.iterrows():
            if pd.isna(fila[var]):
                hora = fila['HORA']
                fecha = fila['FECHA']

                # Buscar el valor del día anterior
                val_ant = grupo[(grupo['HORA'] == hora) & (grupo['FECHA'] < fecha)][var].last_valid_index()
                val_ant = grupo.at[val_ant, var] if val_ant is not None else None

                # Buscar el valor del día posterior
                val_post = grupo[(grupo['HORA'] == hora) & (grupo['FECHA'] > fecha)][var].first_valid_index()
                val_post = grupo.at[val_post, var] if val_post is not None else None

                # Asignar promedio o valor disponible
                if val_ant is not None and val_post is not None:
                    grupo.at[idx, var] = round((val_ant + val_post) / 2, 1)
                elif val_ant is not None:
                    grupo.at[idx, var] = val_ant
                elif val_post is not None:
                    grupo.at[idx, var] = val_post
    return grupo

# Aplicar por estación SIN include_groups
df_interp = (
    df_interp.groupby('NOMBRE', group_keys=False)
    .apply(imputar_valores)
    .reset_index(drop=True)
)

# Redondear valores numéricos a 1 decimal
for var in variables_objetivo:
    df_interp[var] = df_interp[var].round(1)

# Ajustar tipos de columnas
df_interp['HORA'] = df_interp['HORA'].astype('int64')
if 'estacion_archivo' in df_interp.columns:
    df_interp['estacion_archivo'] = df_interp['estacion_archivo'].astype('int64', errors='ignore')

# Exportar
archivo_imputado = PLATA_DIR / "dataset_plata_horario_final.csv"
df_interp.to_csv(archivo_imputado, index=False)
print(f"Archivo exportado: {archivo_imputado}")
# Out:
# Archivo exportado: ../data/plata/dataset_plata_horario_final.csv

# %% [markdown]
# ## Generar archivo diario a partir de la imputación de los datos faltantes en el dato_horario

# %%
# Generar dataset diario imputado (todas las estaciones)

# Agrupar por estación y fecha
df_diario_imputado = df_interp.groupby(['NOMBRE', 'FECHA']).agg(
    TEMP_MEAN=('TEMP', 'mean'),
    TEMP_MIN=('TEMP', 'min'),
    TEMP_MAX=('TEMP', 'max'),
    PNM_MEAN=('PNM', 'mean'),
    PNM_MIN=('PNM', 'min'),
    PNM_MAX=('PNM', 'max'),
    HUM_MEAN=('HUM', 'mean'),
    HUM_MIN=('HUM', 'min'),
    HUM_MAX=('HUM', 'max'),
    WIND_DIR_MEAN=('DD', 'mean'),
    WIND_DIR_MIN=('DD', 'min'),
    WIND_DIR_MAX=('DD', 'max'),
    WIND_SPEED_MEAN=('FF', 'mean'),
    WIND_SPEED_MIN=('FF', 'min'),
    WIND_SPEED_MAX=('FF', 'max')
).reset_index()

# Renombrar y ordenar
df_diario_imputado.rename(columns={'NOMBRE':'ESTACION'}, inplace=True)
df_diario_imputado['FECHA'] = pd.to_datetime(df_diario_imputado['FECHA'])
df_diario_imputado = df_diario_imputado.sort_values(by=['ESTACION','FECHA']).reset_index(drop=True)

# Ajustes de tipos y redondeo

# Redondear medias a 1 decimal
cols_float = ['TEMP_MEAN','PNM_MEAN','HUM_MEAN','WIND_DIR_MEAN','WIND_SPEED_MEAN']
df_diario_imputado[cols_float] = df_diario_imputado[cols_float].round(1)

# Convertir min y max a enteros
cols_int = [
    'TEMP_MIN','TEMP_MAX','PNM_MIN','PNM_MAX',
    'HUM_MIN','HUM_MAX',
    'WIND_DIR_MIN','WIND_DIR_MAX',
    'WIND_SPEED_MIN','WIND_SPEED_MAX'
]
df_diario_imputado[cols_int] = df_diario_imputado[cols_int].round().astype(int)

# Normalización Min-Max de las variables MEAN

variables_mean = ['TEMP_MEAN','PNM_MEAN','HUM_MEAN','WIND_DIR_MEAN','WIND_SPEED_MEAN']
for var in variables_mean:
    col_norm = var + '_NORM'
    min_val = df_diario_imputado[var].min()
    max_val = df_diario_imputado[var].max()
    df_diario_imputado[col_norm] = ((df_diario_imputado[var] - min_val) / (max_val - min_val)).round(5)

# Validación y exportación

print("\nColumnas finales:", df_diario_imputado.columns.tolist())
print("Filas:", len(df_diario_imputado), "| Columnas:", len(df_diario_imputado.columns))
print(df_diario_imputado.groupby('ESTACION').size())

# Guardar el dataset diario imputado completo
archivo_diario_imputado = PLATA_DIR / "dataset_plata_diario_final.csv"
df_diario_imputado.to_csv(archivo_diario_imputado, index=False)
print(f"Archivo diario imputado exportado: {archivo_diario_imputado}")
# Out:
# Columnas finales: ['ESTACION', 'FECHA', 'TEMP_MEAN', 'TEMP_MIN', 'TEMP_MAX', 'PNM_MEAN', 'PNM_MIN', 'PNM_MAX', 'HUM_MEAN', 'HUM_MIN', 'HUM_MAX', 'WIND_DIR_MEAN', 'WIND_DIR_MIN', 'WIND_DIR_MAX', 'WIND_SPEED_MEAN', 'WIND_SPEED_MIN', 'WIND_SPEED_MAX', 'TEMP_MEAN_NORM', 'PNM_MEAN_NORM', 'HUM_MEAN_NORM', 'WIND_DIR_MEAN_NORM', 'WIND_SPEED_MEAN_NORM']
# Filas: 2982 | Columnas: 22
# ESTACION
# CERES AERO            426
# RAFAELA AERO          426
# RECONQUISTA AERO      426
# ROSARIO AERO          426
# SAUCE VIEJO AERO      426
# SUNCHALES AERO        426
# VENADO TUERTO AERO    426
# dtype: int64
# Archivo diario imputado exportado: ../data/plata/dataset_plata_diario_final.csv

# %% [markdown]
# ## Verificar las imputaciones

# %%
# Verificación de imputación final
print("Valores restantes faltantes por variable:")
print(df_interp[variables_objetivo].isnull().sum())

# Vista previa de algunos valores aún faltantes (si existen)
print("\nEjemplos de filas con valores aún faltantes:")
print(df_interp[df_interp[variables_objetivo].isnull().any(axis=1)].head())
# Out:
# Valores restantes faltantes por variable:
# TEMP    0
# HUM     0
# PNM     0
# DD      0
# FF      0
# dtype: int64
#
# Ejemplos de filas con valores aún faltantes:
# Empty DataFrame
# Columns: [NOMBRE, FECHA_HORA, FECHA, HORA, TEMP, HUM, PNM, DD, FF, estacion_archivo]
# Index: []

# %% [markdown]
# # Contar imputaciones por columna

# %%
imputaciones = {}
for var in variables_objetivo:
    # Detectar índices donde original es NaN pero imputado tiene valor
    mask_imputado = df_horario_completo[var].isna() & df_interp[var].notna()
    imputaciones[var] = mask_imputado.sum()

# Mostrar resumen
print("Resumen de imputaciones por variable:")
for var, count in imputaciones.items():
    print(f" - {var}: {count} valores imputados")

# Mostrar ejemplos comparativos (solo filas donde hubo imputación)
print("\nEjemplos de imputaciones realizadas:")
for var in variables_objetivo:
    mask = df_horario_completo[var].isna() & df_interp[var].notna()
    if mask.any():
        print(f"\nVariable: {var}")
        print(df_interp.loc[mask, ['FECHA_HORA', 'NOMBRE', var]])
# Out:
# Resumen de imputaciones por variable:
#  - TEMP: 1213 valores imputados
#  - HUM: 1213 valores imputados
#  - PNM: 1213 valores imputados
#  - DD: 1213 valores imputados
#  - FF: 1213 valores imputados
#
# Ejemplos de imputaciones realizadas:
#
# Variable: TEMP
#                FECHA_HORA              NOMBRE  TEMP
# 1360  2024-07-27 16:00:00          CERES AERO  23.9
# 3308  2024-10-16 20:00:00          CERES AERO  26.8
# 3480  2024-10-24 00:00:00          CERES AERO  23.2
# 3481  2024-10-24 01:00:00          CERES AERO  20.8
# 3482  2024-10-24 02:00:00          CERES AERO  20.8
# ...                   ...                 ...   ...
# 59399 2025-05-24 17:00:00  VENADO TUERTO AERO  20.5
# 59400 2025-05-24 18:00:00  VENADO TUERTO AERO  18.7
# 59409 2025-05-25 11:00:00  VENADO TUERTO AERO  16.8
# 59495 2025-05-30 17:00:00  VENADO TUERTO AERO  17.2
# 59927 2025-06-26 17:00:00  VENADO TUERTO AERO  16.0
#
# [1213 rows x 3 columns]
#
# Variable: HUM
#                FECHA_HORA              NOMBRE   HUM
# 1360  2024-07-27 16:00:00          CERES AERO  30.0
# 3308  2024-10-16 20:00:00          CERES AERO  54.0
# 3480  2024-10-24 00:00:00          CERES AERO  76.0
# 3481  2024-10-24 01:00:00          CERES AERO  80.0
# 3482  2024-10-24 02:00:00          CERES AERO  81.0
# ...                   ...                 ...   ...
# 59399 2025-05-24 17:00:00  VENADO TUERTO AERO  55.0
# 59400 2025-05-24 18:00:00  VENADO TUERTO AERO  65.0
# 59409 2025-05-25 11:00:00  VENADO TUERTO AERO  85.0
# 59495 2025-05-30 17:00:00  VENADO TUERTO AERO  40.0
# 59927 2025-06-26 17:00:00  VENADO TUERTO AERO  20.0
#
# [1213 rows x 3 columns]
#
# Variable: PNM
#                FECHA_HORA              NOMBRE     PNM
# 1360  2024-07-27 16:00:00          CERES AERO  1016.1
# 3308  2024-10-16 20:00:00          CERES AERO  1008.4
# 3480  2024-10-24 00:00:00          CERES AERO  1006.8
# 3481  2024-10-24 01:00:00          CERES AERO  1007.2
# 3482  2024-10-24 02:00:00          CERES AERO  1007.4
# ...                   ...                 ...     ...
# 59399 2025-05-24 17:00:00  VENADO TUERTO AERO  1019.3
# 59400 2025-05-24 18:00:00  VENADO TUERTO AERO  1019.4
# 59409 2025-05-25 11:00:00  VENADO TUERTO AERO  1016.4
# 59495 2025-05-30 17:00:00  VENADO TUERTO AERO  1020.3
# 59927 2025-06-26 17:00:00  VENADO TUERTO AERO  1020.6
#
# [1213 rows x 3 columns]
#
# Variable: DD
#                FECHA_HORA              NOMBRE     DD
# 1360  2024-07-27 16:00:00          CERES AERO  160.0
# 3308  2024-10-16 20:00:00          CERES AERO   70.0
# 3480  2024-10-24 00:00:00          CERES AERO  180.0
# 3481  2024-10-24 01:00:00          CERES AERO  200.0
# 3482  2024-10-24 02:00:00          CERES AERO  190.0
# ...                   ...                 ...    ...
# 59399 2025-05-24 17:00:00  VENADO TUERTO AERO   70.0
# 59400 2025-05-24 18:00:00  VENADO TUERTO AERO   70.0
# 59409 2025-05-25 11:00:00  VENADO TUERTO AERO   50.0
# 59495 2025-05-30 17:00:00  VENADO TUERTO AERO  340.0
# 59927 2025-06-26 17:00:00  VENADO TUERTO AERO  360.0
#
# [1213 rows x 3 columns]
#
# Variable: FF
#                FECHA_HORA              NOMBRE    FF
# 1360  2024-07-27 16:00:00          CERES AERO  24.0
# 3308  2024-10-16 20:00:00          CERES AERO  24.0
# 3480  2024-10-24 00:00:00          CERES AERO  14.5
# 3481  2024-10-24 01:00:00          CERES AERO  13.0
# 3482  2024-10-24 02:00:00          CERES AERO  13.0
# ...                   ...                 ...   ...
# 59399 2025-05-24 17:00:00  VENADO TUERTO AERO   9.0
# 59400 2025-05-24 18:00:00  VENADO TUERTO AERO   9.0
# 59409 2025-05-25 11:00:00  VENADO TUERTO AERO  15.0
# 59495 2025-05-30 17:00:00  VENADO TUERTO AERO   9.0
# 59927 2025-06-26 17:00:00  VENADO TUERTO AERO   4.0
#
# [1213 rows x 3 columns]

# %% [markdown]
# # Visualización de imputación de los días faltantes

# %%
# Carpeta con los archivos de días faltantes
FALTANTES_DIR = Path("../data/faltantes")  # Ajustar al directorio correcto
variables_objetivo = ['TEMP', 'HUM', 'PNM', 'DD', 'FF']

# Función para leer días faltantes de un archivo
def leer_dias_faltantes(file_path):
    with open(file_path, "r") as f:
        lines = f.readlines()
    fechas = [line.strip() for line in lines if line.strip() and line.strip()[0].isdigit()]
    return pd.to_datetime(fechas).date

# Recorrer todos los archivos .txt de días faltantes
faltantes_files = list(FALTANTES_DIR.glob("*.txt"))

resumen_resultados = []

for file_path in faltantes_files:
    estacion = file_path.stem.replace("dias_faltantes_", "").replace("_", " ").upper()
    dias_faltantes = leer_dias_faltantes(file_path)
    
    print(f"\n=== Estación: {estacion} ===")
    resultados_estacion = {"Estación": estacion, "Total días faltantes": len(dias_faltantes), "Días completos": 0, "Días con NaN": 0}
    
    for fecha in dias_faltantes:
        subset_original = df_horario_completo[(df_horario_completo['NOMBRE'].str.upper() == estacion) & (df_horario_completo['FECHA'] == fecha)]
        subset_imputado = df_interp[(df_interp['NOMBRE'].str.upper() == estacion) & (df_interp['FECHA'] == fecha)]
        
        if subset_imputado[variables_objetivo].isnull().any().any():
            resultados_estacion["Días con NaN"] += 1
            print(f"\nFecha {fecha} aún con NaN")
        else:
            resultados_estacion["Días completos"] += 1
            print(f"\nFecha {fecha} imputada correctamente")
        
        # Comparar antes y después
        if not subset_imputado.empty:
            print("\n--- Antes (Original con NaN) ---")
            print(subset_original[['FECHA_HORA', 'NOMBRE'] + variables_objetivo])
            print("\n--- Después (Imputado) ---")
            print(subset_imputado[['FECHA_HORA', 'NOMBRE'] + variables_objetivo])
    
    resumen_resultados.append(resultados_estacion)

# Mostrar resumen final
df_resumen = pd.DataFrame(resumen_resultados)
print("\nResumen de verificación de imputaciones por estación:")
print(df_resumen)
# Out:
# === Estación: VENADO TUERTO AERO ===
#
# Fecha 2024-10-24 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA              NOMBRE  TEMP   HUM     PNM     DD    FF
# 55996 2024-10-24 06:00:00  VENADO TUERTO AERO  15.3  86.0  1009.3  195.0  12.0
# 55997 2024-10-24 07:00:00  VENADO TUERTO AERO  15.4  79.5  1009.2  195.0  15.0
# 55998 2024-10-24 08:00:00  VENADO TUERTO AERO  16.1  86.5  1009.8  205.0  28.5
# 55999 2024-10-24 09:00:00  VENADO TUERTO AERO  16.2  80.5  1010.0  195.0  34.0
# 56000 2024-10-24 10:00:00  VENADO TUERTO AERO  16.2  80.0  1009.0  195.0  40.0
# 56001 2024-10-24 11:00:00  VENADO TUERTO AERO  16.2  80.0  1008.9  195.0  35.5
# 56002 2024-10-24 12:00:00  VENADO TUERTO AERO  16.3  80.0  1009.6  195.0  26.5
# 56003 2024-10-24 13:00:00  VENADO TUERTO AERO  15.3  88.0  1010.0  195.0  12.0
# 56004 2024-10-24 14:00:00  VENADO TUERTO AERO  15.6  91.5  1009.0  195.0  15.0
# 56005 2024-10-24 15:00:00  VENADO TUERTO AERO  18.5  73.0  1008.6  185.0  12.0
# 56006 2024-10-24 16:00:00  VENADO TUERTO AERO  16.0  92.5  1009.3  205.0  14.0
# 56007 2024-10-24 17:00:00  VENADO TUERTO AERO  17.6  88.0  1008.8  205.0   9.0
# 56008 2024-10-24 18:00:00  VENADO TUERTO AERO  18.5  85.0  1009.0  230.0   9.5
# 56009 2024-10-24 19:00:00  VENADO TUERTO AERO  17.8  84.0  1009.8  260.0   9.5
# 56010 2024-10-24 20:00:00  VENADO TUERTO AERO  16.5  89.0  1010.1  260.0   9.5
# 56011 2024-10-24 21:00:00  VENADO TUERTO AERO  16.2  85.5  1011.1  250.0   6.5
#
# Fecha 2024-12-04 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA              NOMBRE  TEMP   HUM     PNM     DD    FF
# 56652 2024-12-04 06:00:00  VENADO TUERTO AERO  10.2  91.5  1012.7   35.0   9.0
# 56653 2024-12-04 07:00:00  VENADO TUERTO AERO  12.3  86.5  1013.1   50.0   6.5
# 56654 2024-12-04 08:00:00  VENADO TUERTO AERO  16.2  66.5  1013.2   35.0  12.0
# 56655 2024-12-04 09:00:00  VENADO TUERTO AERO  19.2  54.0  1013.2  205.0  19.5
# 56656 2024-12-04 10:00:00  VENADO TUERTO AERO  21.6  46.5  1012.6  215.0  15.0
# 56657 2024-12-04 11:00:00  VENADO TUERTO AERO  23.8  52.0  1012.6  225.0  19.5
# 56658 2024-12-04 12:00:00  VENADO TUERTO AERO  25.5  34.0  1011.4  225.0  12.0
# 56659 2024-12-04 13:00:00  VENADO TUERTO AERO  26.7  31.0  1011.1  250.0   9.0
# 56660 2024-12-04 14:00:00  VENADO TUERTO AERO  27.8  28.5  1010.7  240.0  12.0
# 56661 2024-12-04 15:00:00  VENADO TUERTO AERO  28.2  30.0  1009.6   35.0  16.5
# 56662 2024-12-04 16:00:00  VENADO TUERTO AERO  28.8  27.5  1009.4   50.0  15.0
# 56663 2024-12-04 17:00:00  VENADO TUERTO AERO  28.8  25.5  1009.2   50.0  12.0
# 56664 2024-12-04 18:00:00  VENADO TUERTO AERO  28.5  26.5  1007.6   50.0  12.0
# 56665 2024-12-04 19:00:00  VENADO TUERTO AERO  27.4  32.5  1007.2   60.0   9.5
# 56666 2024-12-04 20:00:00  VENADO TUERTO AERO  22.9  49.0  1007.7   60.0   6.5
# 56667 2024-12-04 21:00:00  VENADO TUERTO AERO  20.6  56.0  1008.0   45.0  12.0
#
# Fecha 2024-12-11 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA              NOMBRE  TEMP   HUM     PNM     DD    FF
# 56764 2024-12-11 06:00:00  VENADO TUERTO AERO  14.6  91.5  1012.2   10.0   2.0
# 56765 2024-12-11 07:00:00  VENADO TUERTO AERO  17.0  83.5  1012.0   45.0   4.0
# 56766 2024-12-11 08:00:00  VENADO TUERTO AERO  19.7  69.0  1012.4  190.0   9.5
# 56767 2024-12-11 09:00:00  VENADO TUERTO AERO  24.4  53.0  1012.8  360.0   9.5
# 56768 2024-12-11 10:00:00  VENADO TUERTO AERO  26.4  51.0  1012.8  350.0  14.0
# 56769 2024-12-11 11:00:00  VENADO TUERTO AERO  27.5  46.0  1012.5  360.0  12.0
# 56770 2024-12-11 12:00:00  VENADO TUERTO AERO  28.7  42.0  1012.5  360.0  12.0
# 56771 2024-12-11 13:00:00  VENADO TUERTO AERO  29.4  41.0  1011.8  360.0  12.0
# 56772 2024-12-11 14:00:00  VENADO TUERTO AERO  30.8  41.0  1011.0  190.0  16.5
# 56773 2024-12-11 15:00:00  VENADO TUERTO AERO  31.4  37.0  1010.2  360.0  12.0
# 56774 2024-12-11 16:00:00  VENADO TUERTO AERO  31.6  35.5  1009.6  360.0  15.0
# 56775 2024-12-11 17:00:00  VENADO TUERTO AERO  31.2  37.0  1009.0  205.0  12.0
# 56776 2024-12-11 18:00:00  VENADO TUERTO AERO  30.8  37.5  1008.6  225.0  12.0
# 56777 2024-12-11 19:00:00  VENADO TUERTO AERO  29.4  41.5  1009.0  235.0   9.0
# 56778 2024-12-11 20:00:00  VENADO TUERTO AERO  24.1  50.5  1010.2  270.0  32.5
# 56779 2024-12-11 21:00:00  VENADO TUERTO AERO  19.9  72.0  1011.8  315.0  18.5
#
# Fecha 2025-01-16 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA              NOMBRE  TEMP   HUM     PNM     DD    FF
# 57340 2025-01-16 06:00:00  VENADO TUERTO AERO  20.2  79.0  1009.6  115.0  12.0
# 57341 2025-01-16 07:00:00  VENADO TUERTO AERO  20.4  75.5  1009.8  100.0  12.0
# 57342 2025-01-16 08:00:00  VENADO TUERTO AERO  23.6  63.0  1010.4   70.0  21.0
# 57343 2025-01-16 09:00:00  VENADO TUERTO AERO  26.3  54.5  1010.6   70.0  16.5
# 57344 2025-01-16 10:00:00  VENADO TUERTO AERO  28.8  44.0  1011.0   55.0  24.0
# 57345 2025-01-16 11:00:00  VENADO TUERTO AERO  28.6  47.0  1012.4  280.0  12.0
# 57346 2025-01-16 12:00:00  VENADO TUERTO AERO  28.4  54.0  1012.4  270.0   9.0
# 57347 2025-01-16 13:00:00  VENADO TUERTO AERO  29.8  45.0  1011.8  100.0   9.0
# 57348 2025-01-16 14:00:00  VENADO TUERTO AERO  30.3  48.5  1011.7  140.0   9.0
# 57349 2025-01-16 15:00:00  VENADO TUERTO AERO  28.1  59.0  1011.6  115.0  12.0
# 57350 2025-01-16 16:00:00  VENADO TUERTO AERO  29.2  55.0  1010.8  100.0  12.0
# 57351 2025-01-16 17:00:00  VENADO TUERTO AERO  29.4  54.0  1010.3   10.0   4.5
# 57352 2025-01-16 18:00:00  VENADO TUERTO AERO  28.9  57.5  1010.0   95.0  15.0
# 57353 2025-01-16 19:00:00  VENADO TUERTO AERO  28.8  56.5  1009.6   80.0  12.0
# 57354 2025-01-16 20:00:00  VENADO TUERTO AERO  27.6  60.5  1009.6   70.0   7.5
# 57355 2025-01-16 21:00:00  VENADO TUERTO AERO  25.5  67.5  1009.6   70.0   7.5
#
# === Estación: RAFAELA AERO ===
#
# Fecha 2024-10-24 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA        NOMBRE  TEMP   HUM     PNM     DD    FF
# 11094 2024-10-24 06:00:00  RAFAELA AERO  17.7  82.5  1012.0   45.0   7.5
# 11095 2024-10-24 09:00:00  RAFAELA AERO  21.9  69.5  1012.1   10.0  14.0
# 11096 2024-10-24 12:00:00  RAFAELA AERO  27.2  52.5  1007.5  125.0  28.5
# 11097 2024-10-24 15:00:00  RAFAELA AERO  28.6  46.0  1007.9  205.0  29.5
# 11098 2024-10-24 18:00:00  RAFAELA AERO  23.4  65.5  1008.7  180.0  30.5
# 11099 2024-10-24 21:00:00  RAFAELA AERO  17.2  76.0  1010.0   90.0  18.5
#
# Fecha 2024-12-04 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA        NOMBRE  TEMP   HUM     PNM     DD    FF
# 11340 2024-12-04 06:00:00  RAFAELA AERO  15.0  79.5  1012.8  115.0   9.0
# 11341 2024-12-04 09:00:00  RAFAELA AERO  20.2  61.5  1013.2   95.0  15.0
# 11342 2024-12-04 12:00:00  RAFAELA AERO  25.8  38.5  1012.8   25.0   7.5
# 11343 2024-12-04 15:00:00  RAFAELA AERO  27.8  34.0  1010.3  225.0  16.5
# 11344 2024-12-04 18:00:00  RAFAELA AERO  27.8  33.0  1007.0   70.0  19.5
# 11345 2024-12-04 21:00:00  RAFAELA AERO  23.8  55.0  1007.4   45.0   4.5
#
# Fecha 2024-12-11 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA        NOMBRE  TEMP   HUM     PNM     DD    FF
# 11382 2024-12-11 06:00:00  RAFAELA AERO  15.8  90.5  1012.1   90.0   4.0
# 11383 2024-12-11 09:00:00  RAFAELA AERO  25.0  62.5  1012.8  195.0  13.0
# 11384 2024-12-11 12:00:00  RAFAELA AERO  29.4  45.0  1011.6   50.0  14.0
# 11385 2024-12-11 15:00:00  RAFAELA AERO  29.0  48.0  1011.1  125.0  16.5
# 11386 2024-12-11 18:00:00  RAFAELA AERO  31.2  37.5  1007.8   70.0  22.5
# 11387 2024-12-11 21:00:00  RAFAELA AERO  24.8  59.5  1008.4   90.0  12.0
#
# Fecha 2025-01-16 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA        NOMBRE  TEMP   HUM     PNM     DD    FF
# 11598 2025-01-16 06:00:00  RAFAELA AERO  21.2  76.5  1009.2  100.0   7.5
# 11599 2025-01-16 09:00:00  RAFAELA AERO  30.0  47.0  1009.6  180.0  13.0
# 11600 2025-01-16 12:00:00  RAFAELA AERO  33.0  38.0  1010.0  170.0  17.0
# 11601 2025-01-16 15:00:00  RAFAELA AERO  35.8  33.5  1008.4  170.0  17.5
# 11602 2025-01-16 18:00:00  RAFAELA AERO  36.8  32.5  1007.0  145.0  11.0
# 11603 2025-01-16 21:00:00  RAFAELA AERO  30.2  50.0  1007.8  155.0   9.5
#
# === Estación: CERES AERO ===
#
# Fecha 2024-10-24 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#               FECHA_HORA      NOMBRE  TEMP   HUM     PNM     DD    FF
# 3480 2024-10-24 00:00:00  CERES AERO  23.2  76.0  1006.8  180.0  14.5
# 3481 2024-10-24 01:00:00  CERES AERO  20.8  80.0  1007.2  200.0  13.0
# 3482 2024-10-24 02:00:00  CERES AERO  20.8  81.0  1007.4  190.0  13.0
# 3483 2024-10-24 03:00:00  CERES AERO  22.6  74.5  1005.4  165.0  14.0
# 3484 2024-10-24 04:00:00  CERES AERO  19.8  89.0  1006.6  180.0   6.0
# 3485 2024-10-24 05:00:00  CERES AERO  19.2  91.0  1006.6  350.0   6.0
# 3486 2024-10-24 06:00:00  CERES AERO  20.8  80.5  1004.6  175.0   9.5
# 3487 2024-10-24 07:00:00  CERES AERO  21.0  80.5  1004.9  185.0   9.5
# 3488 2024-10-24 08:00:00  CERES AERO  24.0  69.0  1005.0  170.0  13.0
# 3489 2024-10-24 09:00:00  CERES AERO  26.7  59.5  1005.4  315.0  14.0
# 3490 2024-10-24 10:00:00  CERES AERO  29.8  44.5  1005.4  270.0  16.0
# 3491 2024-10-24 11:00:00  CERES AERO  31.5  41.5  1005.2  270.0  20.5
# 3492 2024-10-24 12:00:00  CERES AERO  31.0  43.0  1005.8  245.0  26.0
# 3493 2024-10-24 13:00:00  CERES AERO  30.3  41.0  1005.7  240.0  30.0
# 3494 2024-10-24 14:00:00  CERES AERO  30.4  37.5  1005.7  240.0  31.5
# 3495 2024-10-24 15:00:00  CERES AERO  29.8  37.5  1005.8  240.0  33.0
# 3496 2024-10-24 16:00:00  CERES AERO  28.8  39.5  1005.5  200.0  28.5
# 3497 2024-10-24 17:00:00  CERES AERO  28.2  39.0  1005.3  195.0  25.0
# 3498 2024-10-24 18:00:00  CERES AERO  27.2  41.5  1005.6  175.0  26.0
# 3499 2024-10-24 19:00:00  CERES AERO  25.4  46.5  1006.6  175.0  23.0
# 3500 2024-10-24 20:00:00  CERES AERO  21.8  56.0  1007.8  165.0  24.0
# 3501 2024-10-24 21:00:00  CERES AERO  19.6  67.0  1009.4  145.0  18.5
# 3502 2024-10-24 22:00:00  CERES AERO  21.4  79.0  1004.6  130.0  22.0
# 3503 2024-10-24 23:00:00  CERES AERO  21.0  84.0  1005.8  100.0  19.0
#
# Fecha 2024-12-04 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#               FECHA_HORA      NOMBRE  TEMP   HUM     PNM     DD    FF
# 4464 2024-12-04 00:00:00  CERES AERO  17.9  64.0  1011.0   90.0  11.0
# 4465 2024-12-04 01:00:00  CERES AERO  17.8  66.5  1011.0   80.0  11.0
# 4466 2024-12-04 02:00:00  CERES AERO  17.8  66.0  1010.7   80.0  11.0
# 4467 2024-12-04 03:00:00  CERES AERO  16.8  70.0  1010.6   70.0  10.5
# 4468 2024-12-04 04:00:00  CERES AERO  17.0  71.0  1010.2   75.0  11.0
# 4469 2024-12-04 05:00:00  CERES AERO  17.0  71.0  1010.6   65.0   7.5
# 4470 2024-12-04 06:00:00  CERES AERO  17.2  72.0  1011.0   45.0   6.5
# 4471 2024-12-04 07:00:00  CERES AERO  18.6  67.5  1011.4   65.0   9.5
# 4472 2024-12-04 08:00:00  CERES AERO  20.8  57.5  1011.9   75.0  16.0
# 4473 2024-12-04 09:00:00  CERES AERO  22.2  51.5  1012.0   70.0  18.0
# 4474 2024-12-04 10:00:00  CERES AERO  24.8  47.5  1012.0   65.0  16.0
# 4475 2024-12-04 11:00:00  CERES AERO  26.4  41.0  1011.2  220.0  17.5
# 4476 2024-12-04 12:00:00  CERES AERO  28.9  33.5  1010.7  235.0  15.0
# 4477 2024-12-04 13:00:00  CERES AERO  29.6  31.5  1009.8  235.0  16.0
# 4478 2024-12-04 14:00:00  CERES AERO  30.1  30.0  1008.9  225.0  15.0
# 4479 2024-12-04 15:00:00  CERES AERO  31.0  29.0  1007.8  245.0  14.0
# 4480 2024-12-04 16:00:00  CERES AERO  31.6  28.0  1006.8   75.0  17.0
# 4481 2024-12-04 17:00:00  CERES AERO  31.3  30.0  1006.1   75.0  18.5
# 4482 2024-12-04 18:00:00  CERES AERO  30.3  35.5  1005.9   70.0  19.5
# 4483 2024-12-04 19:00:00  CERES AERO  29.2  34.5  1005.7   75.0  19.5
# 4484 2024-12-04 20:00:00  CERES AERO  27.3  40.0  1006.0   70.0  14.0
# 4485 2024-12-04 21:00:00  CERES AERO  25.6  51.0  1006.8   65.0  10.5
# 4486 2024-12-04 22:00:00  CERES AERO  24.4  58.5  1007.4   45.0  12.5
# 4487 2024-12-04 23:00:00  CERES AERO  23.2  63.0  1007.7   60.0  12.5
#
# Fecha 2024-12-11 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#               FECHA_HORA      NOMBRE  TEMP   HUM     PNM     DD    FF
# 4632 2024-12-11 00:00:00  CERES AERO  21.0  66.5  1012.0   55.0  12.0
# 4633 2024-12-11 01:00:00  CERES AERO  20.7  71.5  1011.8   50.0  10.5
# 4634 2024-12-11 02:00:00  CERES AERO  20.1  73.0  1011.3   55.0   9.5
# 4635 2024-12-11 03:00:00  CERES AERO  19.6  75.0  1010.8   35.0   8.5
# 4636 2024-12-11 04:00:00  CERES AERO  19.2  77.0  1010.6   75.0   6.5
# 4637 2024-12-11 05:00:00  CERES AERO  18.7  79.0  1010.6   70.0   5.5
# 4638 2024-12-11 06:00:00  CERES AERO  18.0  80.0  1010.8   65.0   7.5
# 4639 2024-12-11 07:00:00  CERES AERO  19.4  78.5  1011.3   45.0   9.5
# 4640 2024-12-11 08:00:00  CERES AERO  21.8  75.5  1011.6   55.0  10.0
# 4641 2024-12-11 09:00:00  CERES AERO  26.4  56.0  1011.8   50.0  15.0
# 4642 2024-12-11 10:00:00  CERES AERO  27.4  48.0  1011.9   40.0  14.0
# 4643 2024-12-11 11:00:00  CERES AERO  29.1  41.5  1011.4   40.0  12.0
# 4644 2024-12-11 12:00:00  CERES AERO  30.6  38.5  1010.8   60.0  14.0
# 4645 2024-12-11 13:00:00  CERES AERO  30.8  37.0  1010.2  360.0  13.0
# 4646 2024-12-11 14:00:00  CERES AERO  31.6  35.5  1009.0   55.0  10.0
# 4647 2024-12-11 15:00:00  CERES AERO  32.4  34.5  1007.7   60.0  12.0
# 4648 2024-12-11 16:00:00  CERES AERO  33.4  34.5  1006.8  190.0  12.0
# 4649 2024-12-11 17:00:00  CERES AERO  33.8  33.5  1005.8   45.0  15.0
# 4650 2024-12-11 18:00:00  CERES AERO  33.1  35.5  1005.2   50.0  17.0
# 4651 2024-12-11 19:00:00  CERES AERO  31.6  38.5  1005.1   55.0  15.0
# 4652 2024-12-11 20:00:00  CERES AERO  29.8  40.5  1005.3   40.0  12.0
# 4653 2024-12-11 21:00:00  CERES AERO  26.8  50.0  1005.9   50.0  12.0
# 4654 2024-12-11 22:00:00  CERES AERO  25.8  56.0  1007.0   55.0  11.0
# 4655 2024-12-11 23:00:00  CERES AERO  25.4  57.5  1007.2   45.0  13.0
#
# Fecha 2025-01-16 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#               FECHA_HORA      NOMBRE  TEMP   HUM     PNM     DD    FF
# 5496 2025-01-16 00:00:00  CERES AERO  26.9  55.5  1007.1   45.0   4.5
# 5497 2025-01-16 01:00:00  CERES AERO  22.2  81.0  1007.8   70.0   7.0
# 5498 2025-01-16 02:00:00  CERES AERO  22.2  78.0  1007.6   80.0   7.0
# 5499 2025-01-16 03:00:00  CERES AERO  24.0  57.5  1006.8  120.0   6.5
# 5500 2025-01-16 04:00:00  CERES AERO  21.6  79.0  1007.6   70.0   6.0
# 5501 2025-01-16 05:00:00  CERES AERO  21.4  79.0  1007.6   50.0   6.0
# 5502 2025-01-16 06:00:00  CERES AERO  22.0  71.0  1008.1  155.0   7.5
# 5503 2025-01-16 07:00:00  CERES AERO  22.4  66.0  1007.8  100.0   6.0
# 5504 2025-01-16 08:00:00  CERES AERO  26.5  52.0  1008.8  195.0  14.0
# 5505 2025-01-16 09:00:00  CERES AERO  30.4  40.5  1009.2  165.0  15.0
# 5506 2025-01-16 10:00:00  CERES AERO  31.8  41.5  1009.7  150.0  19.5
# 5507 2025-01-16 11:00:00  CERES AERO  32.8  36.0  1009.7  115.0  18.5
# 5508 2025-01-16 12:00:00  CERES AERO  34.4  33.5  1009.4  170.0  17.5
# 5509 2025-01-16 13:00:00  CERES AERO  35.0  33.5  1008.8  180.0  19.5
# 5510 2025-01-16 14:00:00  CERES AERO  36.0  30.5  1007.8  180.0  20.5
# 5511 2025-01-16 15:00:00  CERES AERO  36.6  29.5  1007.1  145.0  22.5
# 5512 2025-01-16 16:00:00  CERES AERO  36.7  25.5  1006.4  120.0  16.5
# 5513 2025-01-16 17:00:00  CERES AERO  37.3  25.5  1005.4  145.0  14.0
# 5514 2025-01-16 18:00:00  CERES AERO  36.2  27.0  1005.2  115.0  18.0
# 5515 2025-01-16 19:00:00  CERES AERO  35.6  29.0  1005.3  125.0  15.0
# 5516 2025-01-16 20:00:00  CERES AERO  33.8  34.0  1005.6  130.0  11.0
# 5517 2025-01-16 21:00:00  CERES AERO  31.8  39.0  1006.2  130.0  12.0
# 5518 2025-01-16 22:00:00  CERES AERO  27.4  58.0  1006.4  190.0   4.0
# 5519 2025-01-16 23:00:00  CERES AERO  26.6  60.0  1006.6  200.0   4.0
#
# === Estación: RECONQUISTA AERO ===
#
# Fecha 2024-10-24 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA            NOMBRE  TEMP   HUM     PNM     DD    FF
# 16260 2024-10-24 00:00:00  RECONQUISTA AERO  22.4  84.5  1007.6  205.0   7.5
# 16261 2024-10-24 01:00:00  RECONQUISTA AERO  22.0  84.5  1007.4  200.0  11.0
# 16262 2024-10-24 02:00:00  RECONQUISTA AERO  22.0  85.0  1007.2  175.0  12.0
# 16263 2024-10-24 03:00:00  RECONQUISTA AERO  21.8  85.0  1006.6  190.0  13.0
# 16264 2024-10-24 04:00:00  RECONQUISTA AERO  20.8  89.0  1006.2  190.0   9.0
# 16265 2024-10-24 05:00:00  RECONQUISTA AERO  20.5  90.0  1006.0  180.0   8.0
# 16266 2024-10-24 06:00:00  RECONQUISTA AERO  19.6  93.0  1006.1  185.0   9.0
# 16267 2024-10-24 07:00:00  RECONQUISTA AERO  20.0  92.0  1006.5  190.0   9.0
# 16268 2024-10-24 08:00:00  RECONQUISTA AERO  22.9  83.5  1006.8  185.0  15.5
# 16269 2024-10-24 09:00:00  RECONQUISTA AERO  25.6  67.5  1007.0  150.0  17.5
# 16270 2024-10-24 10:00:00  RECONQUISTA AERO  28.2  62.5  1006.8  155.0  17.5
# 16271 2024-10-24 11:00:00  RECONQUISTA AERO  30.2  54.5  1006.3   90.0  19.5
# 16272 2024-10-24 12:00:00  RECONQUISTA AERO  31.4  46.5  1006.0  265.0  17.5
# 16273 2024-10-24 13:00:00  RECONQUISTA AERO  32.8  45.0  1005.3  295.0  13.5
# 16274 2024-10-24 14:00:00  RECONQUISTA AERO  33.4  41.5  1004.4  275.0  14.5
# 16275 2024-10-24 15:00:00  RECONQUISTA AERO  33.6  40.5  1003.8  300.0  18.5
# 16276 2024-10-24 16:00:00  RECONQUISTA AERO  33.8  39.0  1003.1  300.0  20.5
# 16277 2024-10-24 17:00:00  RECONQUISTA AERO  32.0  45.5  1003.6  280.0  31.5
# 16278 2024-10-24 18:00:00  RECONQUISTA AERO  30.4  47.0  1004.2  280.0  31.5
# 16279 2024-10-24 19:00:00  RECONQUISTA AERO  28.6  49.0  1005.0  110.0  26.0
# 16280 2024-10-24 20:00:00  RECONQUISTA AERO  26.3  54.0  1006.2  110.0  20.0
# 16281 2024-10-24 21:00:00  RECONQUISTA AERO  24.9  62.5  1007.2  120.0  23.5
# 16282 2024-10-24 22:00:00  RECONQUISTA AERO  24.0  67.0  1007.8  100.0  19.0
# 16283 2024-10-24 23:00:00  RECONQUISTA AERO  21.2  71.0  1008.4  200.0  14.0
#
# Fecha 2024-12-04 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA            NOMBRE  TEMP   HUM     PNM     DD    FF
# 17244 2024-12-04 00:00:00  RECONQUISTA AERO  19.0  76.5  1011.6  135.0  10.0
# 17245 2024-12-04 01:00:00  RECONQUISTA AERO  18.5  79.5  1011.6  105.0   9.0
# 17246 2024-12-04 02:00:00  RECONQUISTA AERO  17.9  80.5  1011.4  130.0   6.5
# 17247 2024-12-04 03:00:00  RECONQUISTA AERO  17.9  79.0  1011.2  120.0   5.0
# 17248 2024-12-04 04:00:00  RECONQUISTA AERO  17.2  84.5  1011.4   50.0   5.0
# 17249 2024-12-04 05:00:00  RECONQUISTA AERO  16.2  88.0  1011.2   40.0   4.5
# 17250 2024-12-04 06:00:00  RECONQUISTA AERO  16.6  84.5  1011.6  130.0  10.5
# 17251 2024-12-04 07:00:00  RECONQUISTA AERO  17.5  82.5  1011.7   30.0  10.0
# 17252 2024-12-04 08:00:00  RECONQUISTA AERO  20.6  69.5  1012.0   80.0  14.5
# 17253 2024-12-04 09:00:00  RECONQUISTA AERO  23.0  61.0  1012.2   70.0  14.0
# 17254 2024-12-04 10:00:00  RECONQUISTA AERO  25.4  51.0  1012.1   80.0  15.5
# 17255 2024-12-04 11:00:00  RECONQUISTA AERO  26.6  49.0  1012.0   75.0  18.5
# 17256 2024-12-04 12:00:00  RECONQUISTA AERO  27.4  53.5  1011.5   75.0  18.5
# 17257 2024-12-04 13:00:00  RECONQUISTA AERO  28.2  53.5  1010.9   85.0  18.5
# 17258 2024-12-04 14:00:00  RECONQUISTA AERO  28.6  53.0  1010.1   90.0  17.5
# 17259 2024-12-04 15:00:00  RECONQUISTA AERO  28.6  52.5  1009.3  100.0  17.5
# 17260 2024-12-04 16:00:00  RECONQUISTA AERO  29.2  49.0  1008.6   90.0  15.5
# 17261 2024-12-04 17:00:00  RECONQUISTA AERO  28.8  51.5  1007.8   85.0  18.5
# 17262 2024-12-04 18:00:00  RECONQUISTA AERO  28.6  54.5  1007.8  105.0  22.5
# 17263 2024-12-04 19:00:00  RECONQUISTA AERO  27.9  54.0  1007.3  100.0  16.5
# 17264 2024-12-04 20:00:00  RECONQUISTA AERO  25.6  68.0  1007.5  100.0  14.0
# 17265 2024-12-04 21:00:00  RECONQUISTA AERO  24.6  71.5  1007.6   95.0  12.0
# 17266 2024-12-04 22:00:00  RECONQUISTA AERO  23.2  77.0  1008.2  105.0  11.0
# 17267 2024-12-04 23:00:00  RECONQUISTA AERO  23.3  79.0  1008.6  125.0  13.5
#
# Fecha 2024-12-11 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA            NOMBRE  TEMP   HUM     PNM     DD    FF
# 17412 2024-12-11 00:00:00  RECONQUISTA AERO  21.2  80.5  1012.4  100.0   6.5
# 17413 2024-12-11 01:00:00  RECONQUISTA AERO  20.7  82.5  1012.2  150.0   6.0
# 17414 2024-12-11 02:00:00  RECONQUISTA AERO  20.0  85.0  1011.7  145.0   5.5
# 17415 2024-12-11 03:00:00  RECONQUISTA AERO  19.4  85.5  1011.4  135.0   8.0
# 17416 2024-12-11 04:00:00  RECONQUISTA AERO  19.5  85.5  1011.4  135.0   9.0
# 17417 2024-12-11 05:00:00  RECONQUISTA AERO  18.8  87.5  1011.4  140.0   8.0
# 17418 2024-12-11 06:00:00  RECONQUISTA AERO  18.6  88.0  1011.6  135.0   9.0
# 17419 2024-12-11 07:00:00  RECONQUISTA AERO  19.2  86.0  1012.0   40.0   6.5
# 17420 2024-12-11 08:00:00  RECONQUISTA AERO  22.1  74.0  1012.6  105.0  12.0
# 17421 2024-12-11 09:00:00  RECONQUISTA AERO  24.4  61.5  1012.6   90.0  16.0
# 17422 2024-12-11 10:00:00  RECONQUISTA AERO  26.5  55.0  1012.6  100.0  17.5
# 17423 2024-12-11 11:00:00  RECONQUISTA AERO  27.8  52.5  1012.4   95.0  16.5
# 17424 2024-12-11 12:00:00  RECONQUISTA AERO  28.8  51.0  1011.8   95.0  18.5
# 17425 2024-12-11 13:00:00  RECONQUISTA AERO  29.6  49.0  1011.3   80.0  17.5
# 17426 2024-12-11 14:00:00  RECONQUISTA AERO  30.2  49.0  1010.4   85.0  14.0
# 17427 2024-12-11 15:00:00  RECONQUISTA AERO  31.2  44.5  1009.4  100.0  13.0
# 17428 2024-12-11 16:00:00  RECONQUISTA AERO  31.6  45.0  1008.6  110.0  18.5
# 17429 2024-12-11 17:00:00  RECONQUISTA AERO  31.0  47.0  1007.7   90.0  17.0
# 17430 2024-12-11 18:00:00  RECONQUISTA AERO  30.6  48.5  1007.3  110.0  16.0
# 17431 2024-12-11 19:00:00  RECONQUISTA AERO  30.0  49.5  1007.0   90.0  15.0
# 17432 2024-12-11 20:00:00  RECONQUISTA AERO  28.3  60.5  1007.0  105.0   8.5
# 17433 2024-12-11 21:00:00  RECONQUISTA AERO  26.6  67.5  1007.4  105.0   6.5
# 17434 2024-12-11 22:00:00  RECONQUISTA AERO  26.0  69.5  1007.8   95.0   8.5
# 17435 2024-12-11 23:00:00  RECONQUISTA AERO  25.2  71.0  1008.4   85.0   9.0
#
# Fecha 2025-01-16 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA            NOMBRE  TEMP   HUM     PNM     DD    FF
# 18276 2025-01-16 00:00:00  RECONQUISTA AERO  26.8  61.0  1007.2  200.0  10.0
# 18277 2025-01-16 01:00:00  RECONQUISTA AERO  26.6  64.0  1007.3  155.0  10.0
# 18278 2025-01-16 02:00:00  RECONQUISTA AERO  25.8  67.0  1007.0  130.0  11.0
# 18279 2025-01-16 03:00:00  RECONQUISTA AERO  24.8  70.5  1006.7  145.0  10.0
# 18280 2025-01-16 04:00:00  RECONQUISTA AERO  24.2  74.0  1006.6  115.0   8.0
# 18281 2025-01-16 05:00:00  RECONQUISTA AERO  23.8  75.5  1006.5   95.0   8.0
# 18282 2025-01-16 06:00:00  RECONQUISTA AERO  22.9  79.5  1007.2  130.0   5.5
# 18283 2025-01-16 07:00:00  RECONQUISTA AERO  23.2  80.5  1007.8   90.0   5.0
# 18284 2025-01-16 08:00:00  RECONQUISTA AERO  25.7  72.0  1008.4   35.0  10.0
# 18285 2025-01-16 09:00:00  RECONQUISTA AERO  28.2  64.5  1009.0  190.0   8.0
# 18286 2025-01-16 10:00:00  RECONQUISTA AERO  31.8  53.0  1009.2   40.0   5.0
# 18287 2025-01-16 11:00:00  RECONQUISTA AERO  34.4  42.0  1009.0  155.0   7.5
# 18288 2025-01-16 12:00:00  RECONQUISTA AERO  36.1  39.0  1008.7  170.0  13.0
# 18289 2025-01-16 13:00:00  RECONQUISTA AERO  36.4  36.5  1008.2  115.0  18.0
# 18290 2025-01-16 14:00:00  RECONQUISTA AERO  36.6  36.0  1007.6  125.0  16.0
# 18291 2025-01-16 15:00:00  RECONQUISTA AERO  37.0  34.0  1006.8   90.0  18.0
# 18292 2025-01-16 16:00:00  RECONQUISTA AERO  37.9  30.5  1006.3  120.0  18.0
# 18293 2025-01-16 17:00:00  RECONQUISTA AERO  37.0  33.5  1005.8  115.0  18.5
# 18294 2025-01-16 18:00:00  RECONQUISTA AERO  37.4  34.5  1005.6  140.0  17.0
# 18295 2025-01-16 19:00:00  RECONQUISTA AERO  35.9  36.0  1005.7  145.0  20.5
# 18296 2025-01-16 20:00:00  RECONQUISTA AERO  33.2  45.5  1006.4  160.0   9.0
# 18297 2025-01-16 21:00:00  RECONQUISTA AERO  31.0  53.0  1006.9  115.0  10.0
# 18298 2025-01-16 22:00:00  RECONQUISTA AERO  30.0  58.5  1007.4  110.0  10.0
# 18299 2025-01-16 23:00:00  RECONQUISTA AERO  29.0  63.0  1007.8  100.0  10.0
#
# === Estación: SAUCE VIEJO AERO ===
#
# Fecha 2024-10-24 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA            NOMBRE  TEMP   HUM     PNM     DD    FF
# 36708 2024-10-24 00:00:00  SAUCE VIEJO AERO  20.8  86.0  1007.3  240.0  13.5
# 36709 2024-10-24 01:00:00  SAUCE VIEJO AERO  20.2  87.0  1006.6  230.0  11.5
# 36710 2024-10-24 02:00:00  SAUCE VIEJO AERO  20.0  87.5  1006.1   90.0  10.5
# 36711 2024-10-24 03:00:00  SAUCE VIEJO AERO  19.6  89.5  1005.8  250.0  11.0
# 36712 2024-10-24 04:00:00  SAUCE VIEJO AERO  19.4  89.0  1005.2   80.0  12.5
# 36713 2024-10-24 05:00:00  SAUCE VIEJO AERO  19.5  89.0  1005.2  235.0  10.0
# 36714 2024-10-24 06:00:00  SAUCE VIEJO AERO  19.4  89.5  1005.5   55.0  10.0
# 36715 2024-10-24 07:00:00  SAUCE VIEJO AERO  19.8  86.0  1005.8   55.0   7.5
# 36716 2024-10-24 08:00:00  SAUCE VIEJO AERO  21.8  78.0  1005.7  215.0  13.0
# 36717 2024-10-24 09:00:00  SAUCE VIEJO AERO  23.7  73.0  1005.5  205.0  14.0
# 36718 2024-10-24 10:00:00  SAUCE VIEJO AERO  26.0  63.5  1005.9  160.0  23.5
# 36719 2024-10-24 11:00:00  SAUCE VIEJO AERO  23.6  73.0  1006.8  250.0  38.5
# 36720 2024-10-24 12:00:00  SAUCE VIEJO AERO  23.7  71.0  1006.8  230.0  30.5
# 36721 2024-10-24 13:00:00  SAUCE VIEJO AERO  23.0  76.0  1007.2  215.0  34.5
# 36722 2024-10-24 14:00:00  SAUCE VIEJO AERO  23.9  71.0  1007.0  205.0  37.0
# 36723 2024-10-24 15:00:00  SAUCE VIEJO AERO  23.5  71.0  1006.8  205.0  36.0
# 36724 2024-10-24 16:00:00  SAUCE VIEJO AERO  23.0  65.5  1006.8  205.0  36.0
# 36725 2024-10-24 17:00:00  SAUCE VIEJO AERO  21.5  74.0  1007.0  185.0  18.5
# 36726 2024-10-24 18:00:00  SAUCE VIEJO AERO  21.0  78.0  1007.4  185.0  24.0
# 36727 2024-10-24 19:00:00  SAUCE VIEJO AERO  20.5  78.5  1007.8  205.0  20.5
# 36728 2024-10-24 20:00:00  SAUCE VIEJO AERO  19.4  85.5  1009.6  205.0  13.0
# 36729 2024-10-24 21:00:00  SAUCE VIEJO AERO  18.6  86.0  1009.4  190.0  17.5
# 36730 2024-10-24 22:00:00  SAUCE VIEJO AERO  17.7  91.0  1009.6  205.0  13.0
# 36731 2024-10-24 23:00:00  SAUCE VIEJO AERO  16.4  90.0  1010.2  250.0  13.0
#
# Fecha 2024-12-04 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA            NOMBRE  TEMP   HUM     PNM     DD    FF
# 37692 2024-12-04 00:00:00  SAUCE VIEJO AERO  18.4  70.5  1011.0  150.0   9.5
# 37693 2024-12-04 01:00:00  SAUCE VIEJO AERO  17.6  73.5  1011.4  145.0   9.5
# 37694 2024-12-04 02:00:00  SAUCE VIEJO AERO  17.2  74.5  1011.6  115.0   9.0
# 37695 2024-12-04 03:00:00  SAUCE VIEJO AERO  16.5  79.0  1011.8  135.0   8.0
# 37696 2024-12-04 04:00:00  SAUCE VIEJO AERO  15.9  78.0  1011.8  135.0  12.0
# 37697 2024-12-04 05:00:00  SAUCE VIEJO AERO  15.6  76.5  1012.1  135.0  10.0
# 37698 2024-12-04 06:00:00  SAUCE VIEJO AERO  15.6  73.0  1012.4  125.0  14.0
# 37699 2024-12-04 07:00:00  SAUCE VIEJO AERO  16.0  71.5  1012.7  135.0  17.5
# 37700 2024-12-04 08:00:00  SAUCE VIEJO AERO  17.8  65.0  1013.0  125.0  16.5
# 37701 2024-12-04 09:00:00  SAUCE VIEJO AERO  20.1  54.5  1013.2  135.0  15.0
# 37702 2024-12-04 10:00:00  SAUCE VIEJO AERO  22.0  50.5  1012.9  105.0  19.5
# 37703 2024-12-04 11:00:00  SAUCE VIEJO AERO  23.5  46.5  1012.5  125.0  18.5
# 37704 2024-12-04 12:00:00  SAUCE VIEJO AERO  25.2  42.5  1012.0  105.0  21.5
# 37705 2024-12-04 13:00:00  SAUCE VIEJO AERO  26.0  41.0  1011.5  115.0  17.5
# 37706 2024-12-04 14:00:00  SAUCE VIEJO AERO  26.6  37.0  1010.3   80.0  17.5
# 37707 2024-12-04 15:00:00  SAUCE VIEJO AERO  27.4  33.0  1009.6  105.0  14.0
# 37708 2024-12-04 16:00:00  SAUCE VIEJO AERO  28.0  31.0  1008.6   95.0  17.5
# 37709 2024-12-04 17:00:00  SAUCE VIEJO AERO  28.4  33.5  1007.7   70.0  16.5
# 37710 2024-12-04 18:00:00  SAUCE VIEJO AERO  28.2  35.0  1007.4  135.0  15.5
# 37711 2024-12-04 19:00:00  SAUCE VIEJO AERO  27.6  38.5  1007.4   70.0  11.0
# 37712 2024-12-04 20:00:00  SAUCE VIEJO AERO  25.9  52.0  1007.4  115.0  11.0
# 37713 2024-12-04 21:00:00  SAUCE VIEJO AERO  24.6  58.5  1007.8  115.0  10.0
# 37714 2024-12-04 22:00:00  SAUCE VIEJO AERO  23.5  62.0  1008.1  100.0   8.0
# 37715 2024-12-04 23:00:00  SAUCE VIEJO AERO  22.8  64.0  1008.0  140.0   8.0
#
# Fecha 2024-12-11 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA            NOMBRE  TEMP   HUM     PNM     DD    FF
# 37860 2024-12-11 00:00:00  SAUCE VIEJO AERO  21.0  76.0  1012.8  125.0  11.0
# 37861 2024-12-11 01:00:00  SAUCE VIEJO AERO  19.8  81.5  1012.5  115.0   8.0
# 37862 2024-12-11 02:00:00  SAUCE VIEJO AERO  19.8  79.5  1012.2   90.0  10.0
# 37863 2024-12-11 03:00:00  SAUCE VIEJO AERO  20.1  76.5  1011.6   95.0  11.0
# 37864 2024-12-11 04:00:00  SAUCE VIEJO AERO  19.2  77.5  1011.6   70.0  10.0
# 37865 2024-12-11 05:00:00  SAUCE VIEJO AERO  19.2  78.0  1011.8   70.0   8.0
# 37866 2024-12-11 06:00:00  SAUCE VIEJO AERO  18.6  81.0  1012.0   80.0   7.0
# 37867 2024-12-11 07:00:00  SAUCE VIEJO AERO  20.6  74.5  1012.4   55.0   7.5
# 37868 2024-12-11 08:00:00  SAUCE VIEJO AERO  23.2  66.5  1012.7  195.0   9.5
# 37869 2024-12-11 09:00:00  SAUCE VIEJO AERO  25.1  58.5  1013.0  205.0  12.0
# 37870 2024-12-11 10:00:00  SAUCE VIEJO AERO  27.2  50.0  1012.8   35.0  12.5
# 37871 2024-12-11 11:00:00  SAUCE VIEJO AERO  28.4  46.5  1012.4   35.0  11.5
# 37872 2024-12-11 12:00:00  SAUCE VIEJO AERO  29.3  44.0  1012.0  205.0  12.0
# 37873 2024-12-11 13:00:00  SAUCE VIEJO AERO  29.7  43.0  1011.4   90.0  13.0
# 37874 2024-12-11 14:00:00  SAUCE VIEJO AERO  30.2  44.5  1010.4   90.0  14.0
# 37875 2024-12-11 15:00:00  SAUCE VIEJO AERO  30.6  43.0  1009.6   90.0  15.5
# 37876 2024-12-11 16:00:00  SAUCE VIEJO AERO  30.8  41.5  1008.4   80.0  16.0
# 37877 2024-12-11 17:00:00  SAUCE VIEJO AERO  30.7  39.5  1007.6   80.0  17.5
# 37878 2024-12-11 18:00:00  SAUCE VIEJO AERO  30.6  38.5  1007.2   80.0  20.0
# 37879 2024-12-11 19:00:00  SAUCE VIEJO AERO  29.5  39.5  1007.0   70.0  15.0
# 37880 2024-12-11 20:00:00  SAUCE VIEJO AERO  28.0  48.5  1007.2   90.0   9.0
# 37881 2024-12-11 21:00:00  SAUCE VIEJO AERO  26.6  59.5  1007.6  100.0   9.0
# 37882 2024-12-11 22:00:00  SAUCE VIEJO AERO  25.5  63.5  1008.0  135.0  11.0
# 37883 2024-12-11 23:00:00  SAUCE VIEJO AERO  21.8  77.0  1010.8  170.0  27.5
#
# Fecha 2025-01-16 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA            NOMBRE  TEMP   HUM     PNM     DD    FF
# 38724 2025-01-16 00:00:00  SAUCE VIEJO AERO  26.4  62.5  1007.8  170.0   7.5
# 38725 2025-01-16 01:00:00  SAUCE VIEJO AERO  24.4  71.0  1007.6  180.0   5.0
# 38726 2025-01-16 02:00:00  SAUCE VIEJO AERO  23.4  73.0  1007.4  205.0   6.0
# 38727 2025-01-16 03:00:00  SAUCE VIEJO AERO  22.8  76.5  1007.3  195.0   5.0
# 38728 2025-01-16 04:00:00  SAUCE VIEJO AERO  22.1  75.0  1007.2  105.0   8.5
# 38729 2025-01-16 05:00:00  SAUCE VIEJO AERO  22.8  72.0  1007.4  140.0   9.5
# 38730 2025-01-16 06:00:00  SAUCE VIEJO AERO  23.4  69.0  1007.8   95.0  12.0
# 38731 2025-01-16 07:00:00  SAUCE VIEJO AERO  23.0  66.5  1008.6   90.0  12.0
# 38732 2025-01-16 08:00:00  SAUCE VIEJO AERO  25.0  59.5  1009.2   80.0  14.0
# 38733 2025-01-16 09:00:00  SAUCE VIEJO AERO  28.0  53.0  1009.8   55.0  11.0
# 38734 2025-01-16 10:00:00  SAUCE VIEJO AERO  29.8  47.5  1009.9  250.0   8.5
# 38735 2025-01-16 11:00:00  SAUCE VIEJO AERO  33.4  40.0  1010.0  190.0  13.0
# 38736 2025-01-16 12:00:00  SAUCE VIEJO AERO  34.4  36.0  1009.6  185.0  18.5
# 38737 2025-01-16 13:00:00  SAUCE VIEJO AERO  34.8  33.5  1009.0  145.0  14.5
# 38738 2025-01-16 14:00:00  SAUCE VIEJO AERO  35.4  33.0  1008.5  180.0  14.0
# 38739 2025-01-16 15:00:00  SAUCE VIEJO AERO  36.2  31.5  1007.8  200.0  15.0
# 38740 2025-01-16 16:00:00  SAUCE VIEJO AERO  36.7  30.5  1007.2  170.0  11.5
# 38741 2025-01-16 17:00:00  SAUCE VIEJO AERO  36.7  30.0  1006.9  195.0  14.0
# 38742 2025-01-16 18:00:00  SAUCE VIEJO AERO  36.2  32.0  1006.5  145.0  15.0
# 38743 2025-01-16 19:00:00  SAUCE VIEJO AERO  35.2  35.5  1006.4  160.0  12.0
# 38744 2025-01-16 20:00:00  SAUCE VIEJO AERO  32.2  45.0  1007.0  190.0  14.0
# 38745 2025-01-16 21:00:00  SAUCE VIEJO AERO  30.8  48.5  1007.6  190.0  14.5
# 38746 2025-01-16 22:00:00  SAUCE VIEJO AERO  29.2  52.5  1008.6  170.0  14.0
# 38747 2025-01-16 23:00:00  SAUCE VIEJO AERO  28.5  55.0  1009.0  150.0  17.5
#
# === Estación: ROSARIO AERO ===
#
# Fecha 2024-10-24 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA        NOMBRE  TEMP   HUM     PNM     DD    FF
# 26484 2024-10-24 00:00:00  ROSARIO AERO  19.0  88.0  1007.1   40.0  11.0
# 26485 2024-10-24 01:00:00  ROSARIO AERO  18.4  84.5  1006.7   35.0  12.0
# 26486 2024-10-24 02:00:00  ROSARIO AERO  17.8  84.5  1006.0   60.0  13.0
# 26487 2024-10-24 03:00:00  ROSARIO AERO  17.8  84.5  1005.6  160.0  13.0
# 26488 2024-10-24 04:00:00  ROSARIO AERO  17.3  86.0  1005.3  185.0  15.0
# 26489 2024-10-24 05:00:00  ROSARIO AERO  16.9  89.0  1004.8   45.0  15.0
# 26490 2024-10-24 06:00:00  ROSARIO AERO  16.6  91.5  1005.3  185.0  14.0
# 26491 2024-10-24 07:00:00  ROSARIO AERO  17.2  92.5  1005.6  175.0  12.5
# 26492 2024-10-24 08:00:00  ROSARIO AERO  19.6  86.5  1005.6  175.0  15.0
# 26493 2024-10-24 09:00:00  ROSARIO AERO  19.9  81.5  1006.2  160.0  19.5
# 26494 2024-10-24 10:00:00  ROSARIO AERO  20.5  78.0  1007.0  165.0  19.0
# 26495 2024-10-24 11:00:00  ROSARIO AERO  19.8  75.0  1008.1  150.0  29.0
# 26496 2024-10-24 12:00:00  ROSARIO AERO  19.8  74.0  1007.8  155.0  30.0
# 26497 2024-10-24 13:00:00  ROSARIO AERO  19.0  76.5  1007.9  145.0  23.0
# 26498 2024-10-24 14:00:00  ROSARIO AERO  21.0  79.5  1007.6  140.0  21.5
# 26499 2024-10-24 15:00:00  ROSARIO AERO  17.7  88.5  1007.0  170.0  16.5
# 26500 2024-10-24 16:00:00  ROSARIO AERO  17.9  89.0  1007.4  165.0  14.0
# 26501 2024-10-24 17:00:00  ROSARIO AERO  18.8  83.0  1007.6  260.0  15.0
# 26502 2024-10-24 18:00:00  ROSARIO AERO  17.7  85.5  1007.4  105.0  16.0
# 26503 2024-10-24 19:00:00  ROSARIO AERO  18.2  84.0  1008.2  235.0   5.0
# 26504 2024-10-24 20:00:00  ROSARIO AERO  17.2  90.5  1008.6  215.0   6.5
# 26505 2024-10-24 21:00:00  ROSARIO AERO  16.2  96.0  1009.5  240.0   9.5
# 26506 2024-10-24 22:00:00  ROSARIO AERO  16.0  94.0  1009.6  250.0   6.5
# 26507 2024-10-24 23:00:00  ROSARIO AERO  16.1  93.0  1009.8  205.0  10.5
#
# Fecha 2024-12-04 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA        NOMBRE  TEMP   HUM     PNM     DD    FF
# 27468 2024-12-04 00:00:00  ROSARIO AERO  17.0  63.0  1011.6   90.0  10.0
# 27469 2024-12-04 01:00:00  ROSARIO AERO  16.0  68.5  1012.0  250.0  13.0
# 27470 2024-12-04 02:00:00  ROSARIO AERO  15.3  67.5  1012.0   95.0  11.5
# 27471 2024-12-04 03:00:00  ROSARIO AERO  14.3  70.5  1012.1   70.0   9.5
# 27472 2024-12-04 04:00:00  ROSARIO AERO  13.8  71.0  1012.0   75.0  11.0
# 27473 2024-12-04 05:00:00  ROSARIO AERO  13.6  73.5  1012.3   95.0   5.0
# 27474 2024-12-04 06:00:00  ROSARIO AERO  12.2  83.0  1012.6  170.0   3.0
# 27475 2024-12-04 07:00:00  ROSARIO AERO  15.6  64.0  1012.8  235.0   9.0
# 27476 2024-12-04 08:00:00  ROSARIO AERO  18.9  50.5  1013.0   45.0  16.0
# 27477 2024-12-04 09:00:00  ROSARIO AERO  21.0  42.0  1012.8  235.0  19.5
# 27478 2024-12-04 10:00:00  ROSARIO AERO  22.8  39.5  1012.6   65.0  13.0
# 27479 2024-12-04 11:00:00  ROSARIO AERO  24.4  34.0  1012.2  250.0  16.5
# 27480 2024-12-04 12:00:00  ROSARIO AERO  25.4  30.5  1011.5   95.0  18.5
# 27481 2024-12-04 13:00:00  ROSARIO AERO  26.6  25.0  1010.8   55.0  16.5
# 27482 2024-12-04 14:00:00  ROSARIO AERO  27.8  23.5  1009.9   80.0  16.5
# 27483 2024-12-04 15:00:00  ROSARIO AERO  28.0  21.0  1009.0  210.0  16.0
# 27484 2024-12-04 16:00:00  ROSARIO AERO  28.0  22.0  1008.2  215.0  14.0
# 27485 2024-12-04 17:00:00  ROSARIO AERO  28.2  25.0  1007.6  190.0  15.0
# 27486 2024-12-04 18:00:00  ROSARIO AERO  27.8  28.0  1007.3  205.0  13.0
# 27487 2024-12-04 19:00:00  ROSARIO AERO  26.8  34.0  1007.4   50.0  13.0
# 27488 2024-12-04 20:00:00  ROSARIO AERO  24.8  43.0  1007.6   80.0   6.5
# 27489 2024-12-04 21:00:00  ROSARIO AERO  22.3  52.0  1007.8   55.0   5.5
# 27490 2024-12-04 22:00:00  ROSARIO AERO  21.1  57.0  1008.0   70.0   9.0
# 27491 2024-12-04 23:00:00  ROSARIO AERO  21.4  54.5  1007.8   60.0   8.0
#
# Fecha 2024-12-11 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA        NOMBRE  TEMP   HUM     PNM     DD    FF
# 27636 2024-12-11 00:00:00  ROSARIO AERO  20.4  67.0  1012.1   40.0   7.5
# 27637 2024-12-11 01:00:00  ROSARIO AERO  18.4  80.0  1012.2   30.0   2.0
# 27638 2024-12-11 02:00:00  ROSARIO AERO  18.5  75.5  1011.8   45.0   7.5
# 27639 2024-12-11 03:00:00  ROSARIO AERO  18.2  80.0  1011.3   50.0   6.5
# 27640 2024-12-11 04:00:00  ROSARIO AERO  17.6  82.0  1011.2   35.0   7.5
# 27641 2024-12-11 05:00:00  ROSARIO AERO  17.0  83.0  1011.4   40.0   5.5
# 27642 2024-12-11 06:00:00  ROSARIO AERO  16.6  85.0  1011.7   10.0   4.5
# 27643 2024-12-11 07:00:00  ROSARIO AERO  19.0  77.5  1011.9   10.0   5.5
# 27644 2024-12-11 08:00:00  ROSARIO AERO  21.8  66.0  1011.2  170.0  12.0
# 27645 2024-12-11 09:00:00  ROSARIO AERO  24.6  59.0  1012.4  170.0  12.0
# 27646 2024-12-11 10:00:00  ROSARIO AERO  26.4  53.0  1012.4  180.0  10.5
# 27647 2024-12-11 11:00:00  ROSARIO AERO  27.4  49.5  1011.9   35.0  13.0
# 27648 2024-12-11 12:00:00  ROSARIO AERO  28.8  43.0  1011.8  205.0  17.0
# 27649 2024-12-11 13:00:00  ROSARIO AERO  29.6  40.0  1011.0  350.0  12.0
# 27650 2024-12-11 14:00:00  ROSARIO AERO  29.6  41.0  1010.1  360.0   9.5
# 27651 2024-12-11 15:00:00  ROSARIO AERO  30.2  39.5  1009.2   30.0  15.0
# 27652 2024-12-11 16:00:00  ROSARIO AERO  30.3  39.5  1008.4   35.0  13.0
# 27653 2024-12-11 17:00:00  ROSARIO AERO  30.3  41.5  1007.5   35.0  12.0
# 27654 2024-12-11 18:00:00  ROSARIO AERO  30.3  39.5  1007.2   35.0  10.0
# 27655 2024-12-11 19:00:00  ROSARIO AERO  28.9  41.5  1007.4   65.0  11.0
# 27656 2024-12-11 20:00:00  ROSARIO AERO  27.6  48.0  1007.8  105.0  11.0
# 27657 2024-12-11 21:00:00  ROSARIO AERO  26.4  49.5  1008.4  105.0  12.0
# 27658 2024-12-11 22:00:00  ROSARIO AERO  25.6  52.5  1008.9   95.0  12.0
# 27659 2024-12-11 23:00:00  ROSARIO AERO  22.4  60.0  1010.7  115.0  25.0
#
# Fecha 2025-01-16 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA        NOMBRE  TEMP   HUM     PNM     DD    FF
# 28500 2025-01-16 00:00:00  ROSARIO AERO  28.6  50.5  1007.8   90.0  11.0
# 28501 2025-01-16 01:00:00  ROSARIO AERO  27.5  52.5  1007.9   90.0  11.0
# 28502 2025-01-16 02:00:00  ROSARIO AERO  26.5  53.5  1007.6   90.0   9.0
# 28503 2025-01-16 03:00:00  ROSARIO AERO  25.2  56.0  1007.4   90.0   6.0
# 28504 2025-01-16 04:00:00  ROSARIO AERO  23.1  67.0  1007.3  135.0   5.5
# 28505 2025-01-16 05:00:00  ROSARIO AERO  22.0  73.0  1007.7  145.0   8.5
# 28506 2025-01-16 06:00:00  ROSARIO AERO  21.4  74.5  1008.0  195.0   4.5
# 28507 2025-01-16 07:00:00  ROSARIO AERO  22.1  71.0  1009.0  150.0   9.5
# 28508 2025-01-16 08:00:00  ROSARIO AERO  24.6  60.0  1009.7   95.0  14.0
# 28509 2025-01-16 09:00:00  ROSARIO AERO  26.8  53.5  1010.4   95.0  16.5
# 28510 2025-01-16 10:00:00  ROSARIO AERO  28.5  53.0  1010.6   65.0  16.5
# 28511 2025-01-16 11:00:00  ROSARIO AERO  30.3  47.0  1010.4   70.0  17.5
# 28512 2025-01-16 12:00:00  ROSARIO AERO  32.3  41.5  1009.8   65.0  16.5
# 28513 2025-01-16 13:00:00  ROSARIO AERO  33.0  40.0  1009.2   65.0  16.5
# 28514 2025-01-16 14:00:00  ROSARIO AERO  33.8  37.5  1008.8   90.0  13.0
# 28515 2025-01-16 15:00:00  ROSARIO AERO  34.8  34.0  1008.5  115.0  17.0
# 28516 2025-01-16 16:00:00  ROSARIO AERO  34.6  31.5  1008.1  105.0  20.5
# 28517 2025-01-16 17:00:00  ROSARIO AERO  33.6  39.5  1007.8  135.0  15.0
# 28518 2025-01-16 18:00:00  ROSARIO AERO  33.0  39.0  1007.6  115.0  15.0
# 28519 2025-01-16 19:00:00  ROSARIO AERO  32.1  41.5  1007.6  125.0  14.5
# 28520 2025-01-16 20:00:00  ROSARIO AERO  30.6  44.5  1008.0  115.0  16.5
# 28521 2025-01-16 21:00:00  ROSARIO AERO  29.2  50.0  1008.4  115.0  14.5
# 28522 2025-01-16 22:00:00  ROSARIO AERO  27.8  55.5  1009.0  100.0  14.0
# 28523 2025-01-16 23:00:00  ROSARIO AERO  27.0  54.0  1009.4   90.0  17.5
#
# === Estación: SUNCHALES AERO ===
#
# Fecha 2024-10-24 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA          NOMBRE  TEMP   HUM     PNM     DD    FF
# 46932 2024-10-24 00:00:00  SUNCHALES AERO  22.3  77.0  1007.3   45.0   7.5
# 46933 2024-10-24 01:00:00  SUNCHALES AERO  21.3  81.5  1006.8   45.0   4.5
# 46934 2024-10-24 02:00:00  SUNCHALES AERO  20.6  83.0  1006.2   45.0   4.5
# 46935 2024-10-24 03:00:00  SUNCHALES AERO  20.2  83.0  1006.2  190.0  10.5
# 46936 2024-10-24 04:00:00  SUNCHALES AERO  20.4  81.5  1005.4  205.0  12.0
# 46937 2024-10-24 05:00:00  SUNCHALES AERO  20.8  79.0  1005.2  205.0  15.0
# 46938 2024-10-24 06:00:00  SUNCHALES AERO  20.4  82.5  1005.2  205.0  12.0
# 46939 2024-10-24 07:00:00  SUNCHALES AERO  20.8  84.5  1005.7  170.0  14.0
# 46940 2024-10-24 08:00:00  SUNCHALES AERO  22.5  81.0  1006.2  160.0  14.0
# 46941 2024-10-24 09:00:00  SUNCHALES AERO  25.6  68.5  1006.3  145.0  21.0
# 46942 2024-10-24 10:00:00  SUNCHALES AERO  27.8  57.5  1006.6  315.0  24.0
# 46943 2024-10-24 11:00:00  SUNCHALES AERO  27.3  54.0  1007.0  285.0  28.5
# 46944 2024-10-24 12:00:00  SUNCHALES AERO  27.5  51.0  1007.3  260.0  34.0
# 46945 2024-10-24 13:00:00  SUNCHALES AERO  28.4  46.0  1007.1  245.0  35.5
# 46946 2024-10-24 14:00:00  SUNCHALES AERO  28.5  46.0  1007.4  245.0  35.5
# 46947 2024-10-24 15:00:00  SUNCHALES AERO  28.0  48.5  1006.8  245.0  40.0
# 46948 2024-10-24 16:00:00  SUNCHALES AERO  27.1  47.0  1006.8  245.0  40.0
# 46949 2024-10-24 17:00:00  SUNCHALES AERO  25.6  55.5  1006.6  225.0  28.5
# 46950 2024-10-24 18:00:00  SUNCHALES AERO  23.8  59.5  1007.2  225.0  28.5
# 46951 2024-10-24 19:00:00  SUNCHALES AERO  20.6  70.5  1008.4  215.0  16.5
# 46952 2024-10-24 20:00:00  SUNCHALES AERO  18.6  77.0  1009.0  215.0  21.0
# 46953 2024-10-24 21:00:00  SUNCHALES AERO  18.0  80.0  1010.0  215.0  18.5
# 46954 2024-10-24 22:00:00  SUNCHALES AERO  17.2  83.5  1010.2  215.0  14.0
# 46955 2024-10-24 23:00:00  SUNCHALES AERO  15.3  87.5  1011.6  250.0  14.0
#
# Fecha 2024-12-04 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA          NOMBRE  TEMP   HUM     PNM     DD    FF
# 47916 2024-12-04 00:00:00  SUNCHALES AERO  17.8  69.5  1012.0  115.0   6.5
# 47917 2024-12-04 01:00:00  SUNCHALES AERO  16.6  75.0  1011.7  115.0   6.5
# 47918 2024-12-04 02:00:00  SUNCHALES AERO  16.2  77.0  1011.6  115.0   6.5
# 47919 2024-12-04 03:00:00  SUNCHALES AERO  15.4  79.5  1011.4  125.0   4.0
# 47920 2024-12-04 04:00:00  SUNCHALES AERO  15.0  81.5  1011.8  125.0   4.0
# 47921 2024-12-04 05:00:00  SUNCHALES AERO  14.8  82.5  1011.8  125.0   9.5
# 47922 2024-12-04 06:00:00  SUNCHALES AERO  14.5  81.5  1012.0  105.0  12.0
# 47923 2024-12-04 07:00:00  SUNCHALES AERO  15.0  79.5  1013.0   70.0   9.5
# 47924 2024-12-04 08:00:00  SUNCHALES AERO  18.2  67.0  1013.2   80.0  16.5
# 47925 2024-12-04 09:00:00  SUNCHALES AERO  21.0  51.0  1013.5   95.0  19.5
# 47926 2024-12-04 10:00:00  SUNCHALES AERO  22.8  44.5  1013.1   95.0  19.5
# 47927 2024-12-04 11:00:00  SUNCHALES AERO  24.4  40.5  1012.6   95.0  19.5
# 47928 2024-12-04 12:00:00  SUNCHALES AERO  26.4  37.5  1011.8   80.0  19.5
# 47929 2024-12-04 13:00:00  SUNCHALES AERO  27.0  37.0  1011.2   65.0  16.5
# 47930 2024-12-04 14:00:00  SUNCHALES AERO  28.2  35.0  1010.3   65.0  16.5
# 47931 2024-12-04 15:00:00  SUNCHALES AERO  29.2  35.0  1009.2   80.0  14.0
# 47932 2024-12-04 16:00:00  SUNCHALES AERO  29.8  34.5  1008.4   80.0  14.0
# 47933 2024-12-04 17:00:00  SUNCHALES AERO  29.7  33.0  1007.4   80.0  19.5
# 47934 2024-12-04 18:00:00  SUNCHALES AERO  29.2  35.0  1007.2   80.0  15.0
# 47935 2024-12-04 19:00:00  SUNCHALES AERO  27.8  44.0  1007.0   80.0  12.0
# 47936 2024-12-04 20:00:00  SUNCHALES AERO  25.0  59.0  1007.2  100.0   9.0
# 47937 2024-12-04 21:00:00  SUNCHALES AERO  23.0  67.0  1007.6  100.0   6.5
# 47938 2024-12-04 22:00:00  SUNCHALES AERO  22.6  69.0  1007.9  100.0   9.5
# 47939 2024-12-04 23:00:00  SUNCHALES AERO  21.6  74.0  1008.7   35.0  12.0
#
# Fecha 2024-12-11 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA          NOMBRE  TEMP   HUM     PNM     DD    FF
# 48084 2024-12-11 00:00:00  SUNCHALES AERO  20.2  69.0  1012.6   90.0   6.5
# 48085 2024-12-11 01:00:00  SUNCHALES AERO  19.4  73.0  1012.4   55.0   6.5
# 48086 2024-12-11 02:00:00  SUNCHALES AERO  18.9  73.5  1012.1   55.0   6.5
# 48087 2024-12-11 03:00:00  SUNCHALES AERO  17.7  82.0  1011.8   70.0   6.5
# 48088 2024-12-11 04:00:00  SUNCHALES AERO  17.4  83.0  1011.6   45.0   4.5
# 48089 2024-12-11 05:00:00  SUNCHALES AERO  16.6  86.0  1011.8   90.0   6.5
# 48090 2024-12-11 06:00:00  SUNCHALES AERO  16.0  90.0  1012.2   90.0   4.0
# 48091 2024-12-11 07:00:00  SUNCHALES AERO  17.6  88.5  1012.6   35.0   4.5
# 48092 2024-12-11 08:00:00  SUNCHALES AERO  22.2  71.0  1012.8   35.0   9.5
# 48093 2024-12-11 09:00:00  SUNCHALES AERO  25.2  61.0  1012.9   60.0   9.5
# 48094 2024-12-11 10:00:00  SUNCHALES AERO  26.8  54.0  1012.8   25.0  12.0
# 48095 2024-12-11 11:00:00  SUNCHALES AERO  28.2  48.5  1012.4   55.0   9.5
# 48096 2024-12-11 12:00:00  SUNCHALES AERO  29.8  44.0  1011.8   60.0  12.0
# 48097 2024-12-11 13:00:00  SUNCHALES AERO  30.8  40.5  1011.0   70.0  12.0
# 48098 2024-12-11 14:00:00  SUNCHALES AERO  31.2  39.0  1010.2   80.0   9.5
# 48099 2024-12-11 15:00:00  SUNCHALES AERO  32.3  34.5  1009.0   80.0  15.0
# 48100 2024-12-11 16:00:00  SUNCHALES AERO  32.4  35.5  1008.0   80.0  15.0
# 48101 2024-12-11 17:00:00  SUNCHALES AERO  32.2  34.5  1007.0   70.0  24.0
# 48102 2024-12-11 18:00:00  SUNCHALES AERO  31.5  37.0  1006.7   70.0  24.0
# 48103 2024-12-11 19:00:00  SUNCHALES AERO  30.2  40.0  1006.7   70.0  19.5
# 48104 2024-12-11 20:00:00  SUNCHALES AERO  28.4  45.5  1006.6  100.0  19.5
# 48105 2024-12-11 21:00:00  SUNCHALES AERO  25.1  58.0  1007.2   90.0  12.0
# 48106 2024-12-11 22:00:00  SUNCHALES AERO  24.1  61.0  1007.7   90.0  12.0
# 48107 2024-12-11 23:00:00  SUNCHALES AERO  20.4  79.0  1009.2  170.0  32.5
#
# Fecha 2025-01-16 imputada correctamente
#
# --- Antes (Original con NaN) ---
# Empty DataFrame
# Columns: [FECHA_HORA, NOMBRE, TEMP, HUM, PNM, DD, FF]
# Index: []
#
# --- Después (Imputado) ---
#                FECHA_HORA          NOMBRE  TEMP   HUM     PNM     DD    FF
# 48948 2025-01-16 00:00:00  SUNCHALES AERO  25.4  55.0  1008.2  100.0   4.0
# 48949 2025-01-16 01:00:00  SUNCHALES AERO  24.7  59.0  1008.2  100.0   4.0
# 48950 2025-01-16 02:00:00  SUNCHALES AERO  24.2  61.5  1008.0  100.0   4.0
# 48951 2025-01-16 03:00:00  SUNCHALES AERO  23.7  64.0  1007.6  115.0   4.0
# 48952 2025-01-16 04:00:00  SUNCHALES AERO  22.9  67.0  1007.8  115.0   4.0
# 48953 2025-01-16 05:00:00  SUNCHALES AERO  22.2  68.0  1007.4  115.0   4.0
# 48954 2025-01-16 06:00:00  SUNCHALES AERO  21.2  68.5  1007.9  160.0   4.0
# 48955 2025-01-16 07:00:00  SUNCHALES AERO  20.5  74.5  1008.8   70.0   2.0
# 48956 2025-01-16 08:00:00  SUNCHALES AERO  26.0  59.5  1009.5  115.0   4.0
# 48957 2025-01-16 09:00:00  SUNCHALES AERO  30.4  45.5  1010.0  190.0   9.5
# 48958 2025-01-16 10:00:00  SUNCHALES AERO  32.2  39.5  1010.2  150.0   9.0
# 48959 2025-01-16 11:00:00  SUNCHALES AERO  33.1  39.5  1010.4  170.0  12.0
# 48960 2025-01-16 12:00:00  SUNCHALES AERO  33.0  38.5  1010.3  195.0  15.0
# 48961 2025-01-16 13:00:00  SUNCHALES AERO  33.4  37.5  1009.8  160.0  12.0
# 48962 2025-01-16 14:00:00  SUNCHALES AERO  35.4  35.0  1009.2  170.0  12.0
# 48963 2025-01-16 15:00:00  SUNCHALES AERO  36.0  33.0  1008.3  170.0  19.5
# 48964 2025-01-16 16:00:00  SUNCHALES AERO  37.0  32.0  1007.4  170.0  24.0
# 48965 2025-01-16 17:00:00  SUNCHALES AERO  36.6  31.5  1007.0  170.0  19.5
# 48966 2025-01-16 18:00:00  SUNCHALES AERO  35.8  34.0  1006.8  155.0  12.0
# 48967 2025-01-16 19:00:00  SUNCHALES AERO  34.7  37.0  1006.8  155.0  12.0
# 48968 2025-01-16 20:00:00  SUNCHALES AERO  32.6  43.0  1007.0  155.0   9.0
# 48969 2025-01-16 21:00:00  SUNCHALES AERO  30.6  49.5  1007.3  155.0   9.0
# 48970 2025-01-16 22:00:00  SUNCHALES AERO  29.4  52.5  1007.8  135.0  14.0
# 48971 2025-01-16 23:00:00  SUNCHALES AERO  28.2  55.5  1008.6  135.0  14.0
#
# Resumen de verificación de imputaciones por estación:
#              Estación  Total días faltantes  Días completos  Días con NaN
# 0  VENADO TUERTO AERO                     4               4             0
# 1        RAFAELA AERO                     4               4             0
# 2          CERES AERO                     4               4             0
# 3    RECONQUISTA AERO                     4               4             0
# 4    SAUCE VIEJO AERO                     4               4             0
# 5        ROSARIO AERO                     4               4             0
# 6      SUNCHALES AERO                     4               4             0

# %% [markdown]
# # Verificación de datos faltantes

# %%
# Crear un DataFrame reducido solo con días únicos por estación
df_fechas = df_interp[['FECHA', 'NOMBRE']].drop_duplicates()

# Generar rango completo de fechas
fechas_totales = pd.date_range(start=df_fechas['FECHA'].min(), end=df_fechas['FECHA'].max(), freq='D')

# Estaciones
estaciones = df_fechas['NOMBRE'].unique()
# Crear todas las combinaciones posibles (fecha, estación)
index_completo = pd.MultiIndex.from_product([fechas_totales, estaciones], names=['FECHA', 'NOMBRE'])

# Reindexar
df_check = df_fechas.set_index(['FECHA', 'NOMBRE']).reindex(index_completo).reset_index()

# Verificar faltantes
faltantes = df_check[df_check.isnull().any(axis=1)][['NOMBRE', 'FECHA']]

# Exportar resultados
if not faltantes.empty:
    archivo_faltantes_final = PLATA_DIR / "fechas_faltantes_post_imputacion.txt"
    faltantes.to_csv(archivo_faltantes_final, index=False, sep='\t')
    print(f"Fechas faltantes exportadas a: {archivo_faltantes_final}")
else:
    print("No se encontraron fechas faltantes después de la imputación.")

# Vista rápida
print("\nEjemplo de fechas faltantes:")
print(faltantes.head())
# Out:
# No se encontraron fechas faltantes después de la imputación.
#
# Ejemplo de fechas faltantes:
# Empty DataFrame
# Columns: [NOMBRE, FECHA]
# Index: []

# %% [markdown]
# # Conclusión
#
# En este notebook hemos completado el proceso de **enriquecimiento de la Capa Plata**.
#
# Se garantiza:
# - **Datos horarios completos** por estación para el período de análisis.
# - **Tratamiento adecuado de valores faltantes**, aplicando imputaciones coherentes con el comportamiento histórico de cada estación.
# - Generación de un **dataset final imputado** que sirve como base para análisis avanzados (clustering, PCA, detección de eventos).
#
# Con esta preparación, los datos están listos para las tareas de **minería de datos y categorización**, que abordaremos en la clase siguiente.
